# %% [markdown]
# ## Data Exploration
# #### Written by: Isobel Jones
# #### Date: 17th of June
#
# 1. Load and deserialise pickled data
# 2. Define Function that can produce word cloud
# 3. Plot frequencies of word occurances for each different class
# 4. Check to see whether the distribution follows zipfs law

# %%
import os
import math
import pickle
import operator  # Used to return value from key,value pair in dictionary.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns

# %%
#Get current working directory
cwd = os.getcwd()

# %% [markdown]
# #### 1. Load and deserialise pickled data

# %%
def loadData(path):
    #Open the file for reading
    fileObject = open(path,'rb')

    # load the object from the file into var b
    loadedTweets = pickle.load(fileObject)
    return loadedTweets

# %%
def categoriseTweets(data, category):
    tweets = [x for x in data if x[2] == category]
    return tweets

# %%
def producewordCloud(data, category):
    #Join up all the tokenized tweets
    tweets = [" ".join(x[1]) for x in cleanedtweets if x[2]==category]
    joinedtweets = " ".join(tweets)
    wordcloud = WordCloud(width=1600, height=800,max_font_size=200).generate(joinedtweets)
    plt.figure(figsize=(12,10))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
file_name = cwd +'/data/GDPRcompliantTweets.dump'

cleanedtweets = loadData(file_name)
cleanedtweets[0]
# Out:
# (0,
#  ['hey', 'badly', 'parcel', 'telling', 'going', 'nrc', 'reason'],
#  'Find My Item')

# %%
producewordCloud(cleanedtweets, 'Find My Item')

# %%
producewordCloud(cleanedtweets,'Complaint')

# %%
producewordCloud(cleanedtweets, 'Engagement')

# %%
producewordCloud(cleanedtweets, 'Other')

# %%
producewordCloud(cleanedtweets, 'Enquiry')

# %%
#Global feature dictionary

featureDict = {}
# Returns a dictionary containing features as keys, and weights as values

def tofeatureDict(tokens):
    v = {}
    for t in tokens:
        if t in featureDict:
            featureDict[t] = featureDict[t] + 1
        else: 
            featureDict[t] = 0 
        if t in v:
            v[t] = v[t] + 1
        else:
            v[t] = 1
    return v

# %%
def featuredictcategory(category):
    name = category + '_bagofwords'
    name = []
    category = categoriseTweets(cleanedtweets, category)
    for ( id,Tweet,label) in category:
        name.append((tofeatureDict(Tweet),label))

    return name

# %%
def sortedfeaturedictcategory(category):
    name = category + '_bagofwords'
    name = []
    category = categoriseTweets(cleanedtweets, category)
    for ( id,Tweet,label) in category:
        name.append((tofeatureDict(Tweet),label))
    #Show the top 50 most commons words
    sorted_x = sorted(featureDict.items(), key=operator.itemgetter(1))
     
    return sorted_x[-500:]

# %%
#complaintfeaturedict = sortedfeaturedictcategory('Complaint')
engagementfeaturedict = sortedfeaturedictcategory('Engagement')

# %%
engagementfeaturedict
# Out:
# [('quick', 8),
#  ('gdpr', 8),
#  ('course', 8),
#  ('safe', 8),
#  ('solvemymaths', 8),
#  ('pick', 8),
#  ('jobsearch', 8),
#  ('🙏', 8),
#  ('clothes', 8),
#  ('sfengland', 8),
#  ('heart', 8),
#  ('ready', 8),
#  ('richardavent', 8),
#  ('discogs', 8),
#  ('world', 9),
#  ('view', 9),
#  ('plan', 9),
#  ('cause', 9),
#  ('green', 9),
#  ('anyway', 9),
#  ('ah', 9),
#  ('asap', 9),
#  ('losing', 9),
#  ('b', 9),
#  ('voter', 9),
#  ('depot', 9),
#  ('international', 9),
#  ('long', 9),
#  ('myhermes', 9),
#  ('complain', 9),
#  ('taking', 9),
#  ('pic', 9),
#  ('cannot', 9),
#  ('person', 9),
#  ('website', 9),
#  ('poor', 9),
#  ('receive', 9),
#  ('sign', 9),
#  ('money', 9),
#  ('trying', 9),
#  ('true', 9),
#  ('hopefully', 9),
#  ('ups', 9),
#  ('friend', 9),
#  ('proud', 9),
#  ('saw', 9),
#  ('fire', 9),
#  ('privatised', 9),
#  ('bauble', 9),
#  ('heard', 9),
#  ('etc', 9),
#  ('note', 9),
#  ('surely', 9),
#  ('krustyallslopp', 9),
#  ('😱', 9),
#  ('le', 9),
#  ('…', 9),
#  ('corporate', 9),
#  ('mamapie', 9),
#  ('brismithy', 9),
#  ('pdannyh', 9),
#  ('amazing', 10),
#  ('old', 10),
#  ('🌈', 10),
#  ('open', 10),
#  ('however', 10),
#  ('answer', 10),
#  ('employee', 10),
#  ('glad', 10),
#  ('took', 10),
#  ('head', 10),
#  ('shipping', 10),
#  ('car', 10),
#  ('lose', 10),
#  ('luck', 10),
#  ('ami', 10),
#  ('officeshoes', 10),
#  ('bloody', 10),
#  ('😠', 10),
#  ('wonder', 10),
#  ('responsibility', 10),
#  ('given', 10),
#  ('paper', 10),
#  ('😭', 10),
#  ('woman', 10),
#  ('turn', 10),
#  ('site', 10),
#  ('drop', 10),
#  ('anniversary', 10),
#  ('life', 10),
#  ('tarquingroup', 10),
#  ('panlepan', 10),
#  ('heavoffice', 10),
#  ('donation', 10),
#  ('kingkennystand', 10),
#  ('attacked', 10),
#  ('fantastic', 11),
#  ('postbox', 11),
#  ('g', 11),
#  ('congratulation', 11),
#  ('area', 11),
#  ('found', 11),
#  ('😊', 11),
#  ('support', 11),
#  ('design', 11),
#  ('tuesday', 11),
#  ('john', 11),
#  ('labour', 11),
#  ('chance', 11),
#  ('seen', 11),
#  ('info', 11),
#  ('looking', 11),
#  ('custom', 11),
#  ('com', 11),
#  ('probably', 11),
#  ('taken', 11),
#  ('😉', 11),
#  ('set', 11),
#  ('cvazd', 11),
#  ('anyone', 11),
#  ('small', 11),
#  ('nd', 11),
#  ('ridiculous', 11),
#  ('\u200d', 11),
#  ('proxy', 11),
#  ('sound', 11),
#  ('fee', 11),
#  ('stevebrinemp', 11),
#  ('kind', 11),
#  ('better', 11),
#  ('xx', 11),
#  ('fazeypie', 11),
#  ('refund', 11),
#  ('station', 11),
#  ('wanted', 11),
#  ('van', 11),
#  ('rewindhour', 11),
#  ('jeremycorbyn', 11),
#  ('tracking_number', 11),
#  ('display', 11),
#  ('animal', 11),
#  ('early', 11),
#  ('complaint', 11),
#  ('fuck', 11),
#  ('okay', 11),
#  ('glastofest', 11),
#  ('smiggle', 11),
#  ('bonnierpublish', 11),
#  ('grenfell', 11),
#  ('actually', 12),
#  ('happy', 12),
#  ('soon', 12),
#  ('second', 12),
#  ('made', 12),
#  ('tell', 12),
#  ('without', 12),
#  ('terrible', 12),
#  ('mean', 12),
#  ('house', 12),
#  ('saturday', 12),
#  ('full', 12),
#  ('courier', 12),
#  ('awful', 12),
#  ('bad', 12),
#  ('place', 12),
#  ('voting', 12),
#  ('recorded', 12),
#  ('wait', 12),
#  ('least', 12),
#  ('fault', 12),
#  ('sold', 12),
#  ('instead', 12),
#  ('absolutely', 12),
#  ('hell', 12),
#  ('haven', 12),
#  ('joke', 12),
#  ('officialukmail', 12),
#  ('price', 12),
#  ('blame', 12),
#  ('posties', 12),
#  ('driver', 12),
#  ('pride', 12),
#  ('usps', 13),
#  ('separate', 13),
#  ('bike', 13),
#  ('party', 13),
#  ('directly', 13),
#  ('gone', 13),
#  ('form', 13),
#  ('apply', 13),
#  ('feel', 13),
#  ('thatheavykid', 13),
#  ('😤', 13),
#  ('yesterday', 13),
#  ('half', 13),
#  ('close', 13),
#  ('fucking', 13),
#  ('sending', 13),
#  ('side', 13),
#  ('amazonhelp', 13),
#  ('thecwu', 13),
#  ('mytoptweet', 13),
#  ('dolphin', 13),
#  ('mikepugh', 13),
#  ('nselatchmere', 13),
#  ('believe', 14),
#  ('hey', 14),
#  ('cost', 14),
#  ('raise', 14),
#  ('useless', 14),
#  ('try', 14),
#  ('disgusting', 14),
#  ('🤔', 14),
#  ('wow', 14),
#  ('polling', 14),
#  ('devottracking_number', 14),
#  ('award', 14),
#  ('headstogether', 14),
#  ('intercitybr', 14),
#  ('littlelondonbus', 14),
#  ('eastcoastway', 14),
#  ('book', 15),
#  ('part', 15),
#  ('two', 15),
#  ('perhaps', 15),
#  ('postboxcollect', 15),
#  ('option', 15),
#  ('electoralcommuk', 15),
#  ('🙄', 15),
#  ('detail', 15),
#  ('luk', 15),
#  ('enough', 15),
#  ('else', 15),
#  ('signed', 15),
#  ('ordered', 15),
#  ('sorted', 15),
#  ('lol', 15),
#  ('council', 15),
#  ('claim', 15),
#  ('name', 15),
#  ('actionrailuk', 15),
#  ('modelrailclub', 15),
#  ('railexpress', 15),
#  ('railwaymodeller', 15),
#  ('modelrailuk', 15),
#  ('❤', 16),
#  ('yeah', 16),
#  ('centre', 16),
#  ('around', 16),
#  ('👏', 16),
#  ('guy', 16),
#  ('rm', 16),
#  ('stop', 16),
#  ('uklabour', 16),
#  ('message', 16),
#  ('charge', 16),
#  ('buy', 16),
#  ('arrive', 16),
#  ('point', 16),
#  ('reason', 16),
#  ('kensingtonroyal', 16),
#  ('sockcouncil', 16),
#  ('worker', 16),
#  ('carolinerussell', 16),
#  ('tlrailuk', 16),
#  ('away', 17),
#  ('collection', 17),
#  ('late', 17),
#  ('online', 17),
#  ('report', 17),
#  ('fail', 17),
#  ('left', 17),
#  ('give', 17),
#  ('nice', 17),
#  ('big', 17),
#  ('stuff', 17),
#  ('touch', 17),
#  ('man', 17),
#  ('p', 17),
#  ('bit', 17),
#  ('seetickets', 17),
#  ('simonbailey', 17),
#  ('rate', 17),
#  ('impression', 17),
#  ('dpduk', 18),
#  ('read', 18),
#  ('london', 18),
#  ('stacey', 18),
#  ('staff', 18),
#  ('replacement', 18),
#  ('waiting', 18),
#  ('parcelforce', 18),
#  ('waterstonespi', 18),
#  ('🏻', 19),
#  ('always', 19),
#  ('leaflet', 19),
#  ('ge', 19),
#  ('handle', 19),
#  ('used', 19),
#  ('anything', 19),
#  ('paid', 19),
#  ('amazonuk', 19),
#  ('ticket', 19),
#  ('human', 19),
#  ('tom', 19),
#  ('road', 20),
#  ('neighbour', 20),
#  ('phone', 20),
#  ('find', 20),
#  ('collect', 20),
#  ('problem', 20),
#  ('return', 20),
#  ('joaquinphoenix', 20),
#  ('morning', 21),
#  ('love', 21),
#  ('job', 21),
#  ('home', 21),
#  ('thought', 21),
#  ('special', 21),
#  ('yes', 21),
#  ('posted', 21),
#  ('worth', 21),
#  ('leave', 21),
#  ('theladymagazine', 21),
#  ('delivering', 22),
#  ('free', 22),
#  ('keep', 22),
#  ('missing', 22),
#  ('mate', 22),
#  ('royalfamily', 22),
#  ('royallifemag', 22),
#  ('benefituk', 22),
#  ('though', 23),
#  ('tracking', 23),
#  ('happened', 23),
#  ('mine', 23),
#  ('wrong', 23),
#  ('niamhnolan', 23),
#  ('sorting', 24),
#  ('ask', 24),
#  ('contact', 24),
#  ('tory', 24),
#  ('package', 24),
#  ('cwunews', 24),
#  ('julitracking_number', 24),
#  ('palaceshopping', 24),
#  ('blondeamyblog', 24),
#  ('nothing', 25),
#  ('company', 25),
#  ('ever', 25),
#  ('month', 25),
#  ('pay', 25),
#  ('every', 25),
#  ('lot', 26),
#  ('business', 26),
#  ('using', 26),
#  ('must', 26),
#  ('tomorrow', 26),
#  ('maybe', 26),
#  ('photo', 26),
#  ('matalan', 26),
#  ('colinasturgess', 26),
#  ('issue', 27),
#  ('able', 27),
#  ('😡', 27),
#  ('working', 28),
#  ('first', 28),
#  ('election', 28),
#  ('conservative', 28),
#  ('👍', 28),
#  ('mallwoodgreen', 28),
#  ('postie', 29),
#  ('customer', 29),
#  ('via', 29),
#  ('someone', 29),
#  ('also', 29),
#  ('jess', 29),
#  ('where', 29),
#  ('something', 29),
#  ('lfc', 29),
#  ('another', 30),
#  ('best', 30),
#  ('put', 30),
#  ('sort', 30),
#  ('call', 30),
#  ('theexchangesw', 30),
#  ('told', 31),
#  ('make', 31),
#  ('email', 31),
#  ('postage', 31),
#  ('engagement', 31),
#  ('kystyleguy', 31),
#  ('last', 32),
#  ('team', 32),
#  ('might', 32),
#  ('arrived', 33),
#  ('sure', 33),
#  ('come', 33),
#  ('door', 33),
#  ('️', 34),
#  ('right', 34),
#  ('class', 36),
#  ('news', 36),
#  ('uk', 37),
#  ('many', 37),
#  ('going', 38),
#  ('never', 38),
#  ('box', 39),
#  ('use', 39),
#  ('stephen', 39),
#  ('kayburley', 39),
#  ('week', 40),
#  ('take', 40),
#  ('done', 40),
#  ('thing', 40),
#  ('didn', 40),
#  ('let', 41),
#  ('postman', 42),
#  ('dog', 42),
#  ('great', 42),
#  ('bbuk', 42),
#  ('year', 43),
#  ('received', 44),
#  ('work', 44),
#  ('clintonstweet', 44),
#  ('nextofficial', 44),
#  ('marksandspencer', 44),
#  ('somersethouse', 44),
#  ('soapandglory', 44),
#  ('sainsburys', 44),
#  ('tesco', 44),
#  ('monsoonuk', 44),
#  ('waitrose', 44),
#  ('newlookfashion', 44),
#  ('mattjcorner', 44),
#  ('topshop', 44),
#  ('riverisland', 44),
#  ('tkmaxxuk', 44),
#  ('poundland', 44),
#  ('rymanstationery', 44),
#  ('elyswimbledon', 44),
#  ('johnlewisretail', 44),
#  ('selfridges', 44),
#  ('hmcustserv', 44),
#  ('jacquelinegold', 44),
#  ('edwardmonkton', 44),
#  ('mrbrendancox', 44),
#  ('houseoffraser', 44),
#  ('barackobama', 44),
#  ('selbysholloway', 44),
#  ('really', 45),
#  ('oh', 45),
#  ('cineworld', 45),
#  ('morrison', 45),
#  ('delivered', 47),
#  ('johndwalsh', 47),
#  ('address', 48),
#  ('whsmith', 48),
#  ('card', 49),
#  ('postmanpostwoman', 49),
#  ('infoapply', 49),
#  ('new', 51),
#  ('thank', 51),
#  ('driving', 51),
#  ('well', 53),
#  ('send', 53),
#  ('waterstones', 54),
#  ('verynetwork', 54),
#  ('order', 55),
#  ('look', 56),
#  ('£', 58),
#  ('davegantly', 58),
#  ('see', 59),
#  ('number', 64),
#  ('stamp', 65),
#  ('hope', 67),
#  ('good', 69),
#  ('lost', 69),
#  ('tweet', 71),
#  ('sorchaholloway', 78),
#  ('time', 79),
#  ('service', 83),
#  ('ha', 84),
#  ('like', 85),
#  ('😂', 87),
#  ('sorry', 87),
#  ('postoffice', 88),
#  ('office', 92),
#  ('angobansaor', 93),
#  ('parcel', 94),
#  ('katervn', 94),
#  ('deliver', 105),
#  ('postal', 106),
#  ('thanks', 107),
#  ('plymouth', 117),
#  ('vote', 127),
#  ('delivery', 140),
#  ('post', 142),
#  ('mikefabricant', 155),
#  ('mail', 194)]

# %% [markdown]
# #### Tweet Text Visualisation
# How different are the tokens in two of the different classes e.g ('complaint','Engagement')? Stop words will not help much as the same high-frequency works (such as 'the', 'to') will be equally frequent in both classes. If these stop words dominate both of the classes, then a meaningful result will be hard to obtain. The number of words will be limited as words which appear once will only add noise so the minimum number of occurences will be set to 10.

# %%
import seaborn as sns



def plotcategoryfrequencysns(category):
    name = category + 'featuredict'
    name = sortedfeaturedictcategory(category)
    name.sort(key=lambda x: x[1], reverse=True)
    # save the names and their respective scores separately
    # reverse the tuples to go from most frequent to least frequent 
    tokens = list(zip(*name))[0]
    frequency = list(zip(*name))[1]
    x_pos = np.arange(len(tokens))
    highesttoken = frequency[0]
    zipfs =[]

    #Caclualte zipfs law
    [zipfs.append(highesttoken * (1/i[0])) for i in enumerate(frequency) if i[0] > 0 ]
    zipfs.append(zipfs[-1])
    
    # calculate slope and intercept for the linear trend line
    slope, intercept = np.polyfit(x_pos, frequency, 1)
    trendline = intercept + (slope * x_pos)
    
    zipfs_df = pd.DataFrame(
    {'x_pos': x_pos,
     'frequency': frequency,
    })
    
    sns.set(style="whitegrid")
    

    ax = sns.barplot(x='x_pos', y="frequency",  data=zipfs_df)
    #ax.lineplot(x_pos, zipfs, color='blue', linewidth=2, markersize=12, label="Zipfs")
    ax.set_title("Top 500 tokens in Tweets")
    ax.set_xlabel('Top 500 {0} tokens'.format(category))
    ax.set_ylabel('Frequency')
    ax.set_xticks([])
    ax.legend()

    return ax

# %%
plt.subplots(figsize=(12,8))
plotcategoryfrequencysns('Complaint')
# Out:
# /Users/isobeljones/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
# No handles with labels found to put in legend.

# %%
plotcategoryfrequencysns('Engagement')
# Out:
# /Users/isobeljones/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
# No handles with labels found to put in legend.

# %%
plotcategoryfrequencysns('Find My Item ')
# Out:
# /Users/isobeljones/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
# No handles with labels found to put in legend.

# %%
def plotloglogzipfsns(category):
    name = category + 'featuredict'
    name = sortedfeaturedictcategory(category)
    name.sort(key=lambda x: x[1], reverse=True)
    # save the names and their respective scores separately
    # reverse the tuples to go from most frequent to least frequent 
    tokens = list(zip(*name))[0]
    frequency = list(zip(*name))[1]
    x_pos = np.arange(len(tokens))
    highesttoken = frequency[0]
    zipfs =[]

    #Caclualte zipfs law
    [zipfs.append(highesttoken * (1/i[0])) for i in enumerate(frequency) if i[0] > 0 ]
    zipfs.append(zipfs[-1])
    
    # calculate slope and intercept for the linear trend line
    slope, intercept = np.polyfit(x_pos, frequency, 1)
    trendline = intercept + (slope * x_pos)
    
    zipfs = zipfs[-499:]
    x_pos = x_pos[-499:]
    frequency = frequency[-499:]
    
    
    zipfs = [math.log10(x)for x in zipfs]
    x_pos = [math.log10(x) for x in x_pos]
    frequency = [math.log10(x) for x in frequency]
    
    zipfs_df = pd.DataFrame(
    {'x_pos': x_pos,
     'frequency': frequency,
    })
    
    sns.set(style="whitegrid")
    ax = sns.lineplot(x='x_pos', y="frequency",palette='GnBu',  data=zipfs_df,  label="LogLog ")
    ax.plot(x_pos, zipfs, color='blue', linewidth=2, markersize=12, label="Zipfs Law")
    ax.set_title("Zipf plot for tweets tokens")
    ax.set_xlabel('Absolute frequency of token')
    ax.set_ylabel('Frequency rank of token')
    #ax.set_xticks([])
    ax.legend()
    ax.set_yscale('log')
    return ax

# %%
plt.subplots(figsize=(12,8))
plotloglogzipfsns('Find My Item')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5c6e5a0acf70> in <module>()
# ----> 1 plt.subplots(figsize=(12,8))
#       2 plotloglogzipfsns('Find My Item')
#
# NameError: name 'plt' is not defined

# %%
name = x + 'featuredict'
name = sortedfeaturedictcategory(x)
name.sort(key=lambda x: x[1], reverse=True)
# save the names and their respective scores separately
# reverse the tuples to go from most frequent to least frequent 
tokens = list(zip(*name))[0]
frequency = list(zip(*name))[1]
x_pos = np.arange(len(tokens))
highesttoken = frequency[0]
zipfs =[]

#Caclualte zipfs law
[zipfs.append(highesttoken * (1/i[0])) for i in enumerate(frequency) if i[0] > 0 ]
zipfs.append(zipfs[-1])

total_highesttoken =+ highesttoken
total_zipfs = total_zipfs + zipfs
total_frequency = total_frequency + list(frequency)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-56118ec6c3b5> in <module>()
# ----> 1 name = x + 'featuredict'
#       2 name = sortedfeaturedictcategory(x)
#       3 name.sort(key=lambda x: x[1], reverse=True)
#       4 # save the names and their respective scores separately
#       5 # reverse the tuples to go from most frequent to least frequent
#
# NameError: name 'x' is not defined

# %%
import powerlaw

fig=plt.figure(figsize=(12, 10), dpi= 80, facecolor='w', edgecolor='k')


powerlaw.plot_ccdf(zipfs,color='b',label='zipfs distribution' )
powerlaw.plot_ccdf(frequency,color='g', label='Tweet distribution')
plt.xlabel("Token Frequency")
plt.ylabel("CCDF")
plt.title("CCDF of token lengths")
plt.legend()
