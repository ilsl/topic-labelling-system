# %% [markdown]
# ## 4. Data Labelling - Supervised
# #### Written by: Isobel Jones
# #### Date: 22nd of June
#
# 1. Load and deserialise pickled data
# 2. Make the 5 categories contain equal number of instances (reduce class imbalance). This is now not used.
# 3. Split data into 80/20 train/test datasets
# 4. Use a pipline to
#  - Convert tokens into bag of words model count (CountVectorizer)
#  - Reduce weighting to more common terms (TF-IDF)
#  TypeOfClassifiers = [multinomial Naive Bayes,]
#  - Build a TypeOfClassifiers classifier
# 5. Train the multionomial Naive Bayes Classifier
# 6. Predict the labels of the test set dataset

# %%
import os
import nltk
import pickle
import numpy as np
from nltk.classify import NaiveBayesClassifier
from nltk.classify.util import accuracy
from sklearn import cross_validation
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import confusion_matrix, recall_score, precision_score
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import SGDClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from imblearn.over_sampling import RandomOverSampler
from sklearn.decomposition import PCA, NMF
from sklearn.feature_selection import SelectKBest, chi2
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# from flair.data_fetcher import NLPTaskDataFetcher
# from flair.embeddings import WordEmbeddings, FlairEmbeddings, DocumentLSTMEmbeddings
# from flair.models import TextClassifier
# from flair.trainers import ModelTrainer
# from pathlib import Path
# Out:
# /Users/isobeljones/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#Get current working directory
cwd = os.getcwd()

# %% [markdown]
# #### Create function to load and deserialise pickled data

# %%
def loadData(path):
    #Open the file for reading
    fileObject = open(path,'rb')

    # load the object from the file into var b
    loadedTweets = pickle.load(fileObject)
    return loadedTweets

# %% [markdown]
# #### Create functions to separate data into features and labels

# %%
def tweetscategorys(data, category='all'):
    if category == 'all':
        x = [x[:][1:] for x in data]
    elif category == 'alllenghtsame':
        categories = ['Complaint','Other','Find My Item','Engagement','Enquiry']
        x=[]
        for c in categories:
            a = [x[:][1:] for x in data if x[2] == c]#[:391]
            x.extend(a)
    else:
        #This returns one category worth of data (features & labels)
        x = [x[:][1:] for x in data if x[2] == category]
    return x
#Split the data into features and labels
def tweetstofeatures(data):
    if len(data) > 2000:
        x = [x[:][1] for x in data]
    else:
        x = [x[:][:][0] for x in data ]
    return x

def tweetstolabels(data):
    if len(data) > 2000:
        y = [x[:][2] for x in data ]
    else:
        y = [x[:][:][1] for x in data ]
    return y

# %%
file_name = cwd + '/data/GDPRcompliantTweets.dump'

cleanedtweets = loadData(file_name)

# %%
z = tweetscategorys(cleanedtweets) # features & labels
x = tweetstofeatures(cleanedtweets) # features
y = tweetstolabels(cleanedtweets) # labels

#Number of instanes is the same
g = tweetscategorys(cleanedtweets,'alllenghtsame')
xg = [x[:][:][0] for x in g ]
yg = [x[:][:][1] for x in g ]

# %%
#xg= [[' '.join(x)] for x in xg]

# %%
#ros = RandomOverSampler(random_state=777)
#xg, yg = ros.fit_sample(xg, yg)

# %% [markdown]
# #### Split the data into Train Test datasets

# %%
X_train, X_test, y_train, y_test = train_test_split(xg, yg, test_size=0.2)

# %% [markdown]
# #### Oversample the data
# Commented out as not oversampling or undersampling the data anymore

# %%
'''
X_train = [[' '.join(x)] for x in X_train] # Remove tokenisation
X_test = [[' '.join(x)] for x in X_test] # Remove tokenisation
ros = RandomOverSampler()
X_train, y_train = ros.fit_sample(X_train, y_train)
from collections import Counter
print(sorted(Counter(y_train).items()))
'''
# Out:
# "\nX_train = [[' '.join(x)] for x in X_train] # Remove tokenisation\nX_test = [[' '.join(x)] for x in X_test] # Remove tokenisation\nros = RandomOverSampler()\nX_train, y_train = ros.fit_sample(X_train, y_train)\nfrom collections import Counter\nprint(sorted(Counter(y_train).items()))\n"

# %% [markdown]
# #### Remove tokenisation

# %%
X_train = [' '.join(x) for x in X_train] # Remove tokenisation
X_test = [' '.join(x) for x in X_test] # Remove tokenisation

# %% [markdown]
# #### Create function to return detailed metrics of interest which takes a pipeline as input

# %%
classlabels = ['Complaint','Other','Find My Item','Engagement','Enquiry']

def print_classification_matrix(y_test, predicted):
    array = confusion_matrix(y_test, predicted, labels=classlabels)
    df_cm = pd.DataFrame(array, classlabels, classlabels)
    plt.figure(figsize = (10,7))
    sn.set(font_scale=1.4)#for label size
    ax = plt.axes()
    ax.set_title('Confusion Matrix')
    sn.heatmap(df_cm, annot=True,annot_kws={"size": 12},cmap='Blues', fmt='g')# font size
    
def get_results(text_clf):
    text_clf = text_clf.fit(X_train, y_train)
    predicted = text_clf.predict(X_test)
    # Cross Validation with 3 folds
    scores = cross_validation.cross_val_score(text_clf, X_train, y_train, cv=3)
    
    print('Each value is the accuracy score of the support vector classifier when leaving out a different fold.\n', scores)
    print('\nOverall Model Accuracy:', scores.mean())
    print('Labels: ', classlabels)
    print('Recall:', recall_score(y_test, text_clf.predict(X_test), average=None))
    print('Precison:', precision_score(y_test, text_clf.predict(X_test), average=None))

    print_classification_matrix(y_test, predicted)

# %% [markdown]
# ## Train Models
#
# 1. Start of with simple ML algorithm
# 2. Perform optimization with gridsearch to find optimum hyperparameters
# 3. Re-run model using hyperparameters

# %% [markdown]
# ### Multinomial Naive Bayes
# ##### 1. Fit model without any hyperparameters

# %%
text_clf_mb = Pipeline([('vect', CountVectorizer()),
                    ('tfidf', TfidfTransformer()),
                    ('clf', MultinomialNB()),
])
get_results(text_clf_mb)
# Out:
# Each value is the accuracy score of the support vector classifier when leaving out a different fold.
#  [0.58177615 0.57090559 0.58241758]
#
# Overall Model Accuracy: 0.5783664403722687
# Labels:  ['Complaint', 'Other', 'Find My Item', 'Engagement', 'Enquiry']
# Recall: [0.94553882 0.31197302 0.01451906 0.50319829 0.        ]
# Precison: [0.54418139 0.92039801 1.         0.69005848 0.        ]

# %% [markdown]
#  ##### 2. Learn optimal paramters using gridsearch

# %%
parameters = {
    'clf__alpha': [0.001, 0.0001, 0.00001, 0.000001],
    'clf__fit_prior':['True', 'False'],
    'vect__ngram_range':[(1, 2),(1, 3),(1, 5),(1, 7),(1, 9)],
    'tfidf__use_idf':['True', 'False'],
    'tfidf__sublinear_tf':['True', 'False'],
    'tfidf__norm':['l2', 'l1']
}

grid_search = GridSearchCV(text_clf_mb, parameters, n_jobs=3,verbose=1)

grid_search.fit(X_train, y_train)
grid_search.best_score_
grid_search.best_params_
# Out:
# Fitting 3 folds for each of 320 candidates, totalling 960 fits
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=3)]: Done 194 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=3)]: Done 444 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=3)]: Done 794 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=3)]: Done 960 out of 960 | elapsed:  7.6min finished
# {'clf__alpha': 0.001,
#  'clf__fit_prior': 'True',
#  'tfidf__norm': 'l2',
#  'tfidf__sublinear_tf': 'True',
#  'tfidf__use_idf': 'True',
#  'vect__ngram_range': (1, 2)}

# %% [markdown]
# ##### 3. Fit model using hyperparameters learnt above

# %%
text_clf_mb = Pipeline([('vect', CountVectorizer(ngram_range=(1, 3),lowercase=False)),
                    ('tfidf', TfidfTransformer(norm='l1', sublinear_tf=True)),
                    ('clf', MultinomialNB(alpha=1e-3, fit_prior=True)),
])
print('Multinomial Classifier')
get_results(text_clf_mb)
# Out:
# Multinomial Classifier
# Each value is the accuracy score of the support vector classifier when leaving out a different fold.
#  [0.61144288 0.61464355 0.61557741]
#
# Overall Model Accuracy: 0.6138879440804909
# Labels:  ['Complaint', 'Other', 'Find My Item', 'Engagement', 'Enquiry']
# Recall: [0.87427578 0.51770658 0.11978221 0.56183369 0.08333333]
# Precison: [0.5922292  0.85041551 0.45517241 0.63724305 0.63636364]

# %% [markdown]
# ### Stochastic Gradiant Descent
# ##### 1. Fit model without any hyperparameters

# %%
text_clf_sgd = Pipeline([
                        ('tfidf', TfidfVectorizer(ngram_range=(1, 2))),
                      ('clf', SGDClassifier(alpha=1e-4, max_iter=1000 )),
])


text_clf_sgd = text_clf_sgd.fit(X_train, y_train)
predicted_sgd = text_clf_sgd.predict(X_test)

print('SGDClassifier \n')
get_results(text_clf_sgd)
# Out:
# SGDClassifier
#
# Each value is the accuracy score of the support vector classifier when leaving out a different fold.
#  [0.6326334  0.63468208 0.64488143]
#
# Overall Model Accuracy: 0.6373989730827937
# Labels:  ['Complaint', 'Other', 'Find My Item', 'Engagement', 'Enquiry']
# Recall: [0.83951333 0.53962901 0.14700544 0.62473348 0.0952381 ]
# Precison: [0.61450382 0.82901554 0.55102041 0.59432049 0.53333333]

# %% [markdown]
#  ##### 2. Learn optimal paramters using gridsearch

# %%
parameters = {
    'clf__max_iter':[10, 100, 1000],
    'clf__alpha': [0.001, 0.0001, 0.00001, 0.000001],
    'tfidf__ngram_range' : [(1, 2),(1, 3),(1, 5),(1, 7),(1, 9)]
}

#score_func = make_scorer(metrics.f1_score)
#, scoring=score_func
grid_search = GridSearchCV(text_clf_sgd, parameters, n_jobs=3,verbose=1)

grid_search.fit(X_train, y_train)
grid_search.best_score_
grid_search.best_params_
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=3)]: Done 180 out of 180 | elapsed:  6.8min finished
# {'clf__alpha': 0.0001, 'clf__max_iter': 100, 'tfidf__ngram_range': (1, 2)}

# %% [markdown]
# ##### 3. Fit model using hyperparameters learnt above

# %%
text_clf_sgd = Pipeline([
                        ('tfidf', TfidfVectorizer(ngram_range=(1, 2))),
                      ('clf', SGDClassifier(alpha=1e-4, max_iter=1000 ,)),
])


text_clf_sgd = text_clf_sgd.fit(X_train, y_train)
predicted_sgd = text_clf_sgd.predict(X_test)

print('SGDClassifier \n')
get_results(text_clf_sgd)
# Out:
# SGDClassifier
#
# Each value is the accuracy score of the support vector classifier when leaving out a different fold.
#  [0.63282605 0.63468208 0.64488143]
#
# Overall Model Accuracy: 0.6374631867859979
# Labels:  ['Complaint', 'Other', 'Find My Item', 'Engagement', 'Enquiry']
# Recall: [0.83951333 0.53962901 0.14700544 0.62366738 0.0952381 ]
# Precison: [0.61424332 0.82901554 0.55102041 0.59390863 0.53333333]

# %% [markdown]
# ### One Verse Rest
# ##### 1. Fit model without any hyperparameters

# %%
onevrestclassifier = Pipeline([
    ('vectorizer', CountVectorizer(ngram_range=(1, 2))),
    ('tfidf', TfidfTransformer()),
    ('clf', OneVsRestClassifier(MultinomialNB()),)])

print('one v rest \n')
get_results(onevrestclassifier)
# Out:
# one v rest
#
# Each value is the accuracy score of the support vector classifier when leaving out a different fold.
#  [0.57387787 0.5734104  0.57432042]
#
# Overall Model Accuracy: 0.5738695621954876
# Labels:  ['Complaint', 'Other', 'Find My Item', 'Engagement', 'Enquiry']
# Recall: [0.94959444 0.29005059 0.01270417 0.46908316 0.        ]
# Precison: [0.53335503 0.92972973 0.875      0.7028754  0.        ]

# %% [markdown]
#  ##### 2. Learn optimal paramters using gridsearch

# %%
parameters = {
    'tfidf__use_idf':['True', 'False'],
    'tfidf__sublinear_tf':['True', 'False'],
    'tfidf__norm':['l2', 'l1'],
    'vectorizer__ngram_range' : [(1, 2),(1, 3),(1, 5),(1, 7),(1, 9)]
}

#score_func = make_scorer(metrics.f1_score)
#, scoring=score_func
grid_search = GridSearchCV(onevrestclassifier, parameters, n_jobs=3,verbose=1)

grid_search.fit(X_train, y_train)
grid_search.best_score_
grid_search.best_params_
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=3)]: Done 120 out of 120 | elapsed:  1.0min finished
# {'tfidf__norm': 'l2',
#  'tfidf__sublinear_tf': 'True',
#  'tfidf__use_idf': 'True',
#  'vectorizer__ngram_range': (1, 2)}

# %% [markdown]
# ##### 3. Fit model using hyperparameters learnt above

# %%
onevrestclassifier = Pipeline([
    ('vectorizer', CountVectorizer(ngram_range=(1, 2))),
    ('tfidf', TfidfTransformer(norm='l2',sublinear_tf='True')),
    ('clf', OneVsRestClassifier(MultinomialNB()),)])

print('one v rest \n')
get_results(onevrestclassifier)
# Out:
# one v rest
#
# Each value is the accuracy score of the support vector classifier when leaving out a different fold.
#  [0.57329994 0.5734104  0.57412763]
#
# Overall Model Accuracy: 0.5736126578637167
# Labels:  ['Complaint', 'Other', 'Find My Item', 'Engagement', 'Enquiry']
# Recall: [0.95017381 0.29005059 0.01270417 0.46588486 0.        ]
# Precison: [0.53298668 0.92972973 0.875      0.70257235 0.        ]

# %% [markdown]
# ### Linear Support Vector Classifier
# ##### 1. Fit model without any hyperparameters

# %%
linearsvc_classifier = Pipeline([
    ('vectorizer', CountVectorizer(ngram_range=(1, 2))),
    ('tfidf', TfidfTransformer()),
    ('clf', LinearSVC())])

print('LinearSVC \n')
get_results(linearsvc_classifier)
# Out:
# LinearSVC
#
# Each value is the accuracy score of the support vector classifier when leaving out a different fold.
#  [0.62801002 0.6344894  0.63929053]
#
# Overall Model Accuracy: 0.6339299846875237
# Labels:  ['Complaint', 'Other', 'Find My Item', 'Engagement', 'Enquiry']
# Recall: [0.80880649 0.57166948 0.26860254 0.61407249 0.14285714]
# Precison: [0.64331797 0.81294964 0.44179104 0.60759494 0.54545455]

# %% [markdown]
#  ##### 2. Learn optimal paramters using gridsearch

# %%
parameters = {
    'tfidf__use_idf':['True', 'False'],
    'tfidf__sublinear_tf':['True', 'False'],
    'tfidf__norm':['l2', 'l1'],
    'vectorizer__ngram_range' : [(1, 2),(1, 3),(1, 5),(1, 7),(1, 9)]
}

#score_func = make_scorer(metrics.f1_score)
#, scoring=score_func
grid_search = GridSearchCV(linearsvc_classifier, parameters, n_jobs=3,verbose=1)

grid_search.fit(X_train, y_train)
grid_search.best_score_
grid_search.best_params_
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=3)]: Done 120 out of 120 | elapsed:  1.5min finished
# {'tfidf__norm': 'l2',
#  'tfidf__sublinear_tf': 'True',
#  'tfidf__use_idf': 'True',
#  'vectorizer__ngram_range': (1, 2)}

# %% [markdown]
#  ###### 3. Fit model using hyperparameters learnt above# 2. Learn optimal paramters using gridsearch

# %%
linearsvc_classifier = Pipeline([
    ('vectorizer', CountVectorizer(ngram_range=(1, 2))),
    ('tfidf', TfidfTransformer()),
    ('clf', LinearSVC())])

print('LinearSVC \n')
get_results(linearsvc_classifier)
# Out:
# LinearSVC
#
# Each value is the accuracy score of the support vector classifier when leaving out a different fold.
#  [0.62801002 0.6344894  0.63929053]
#
# Overall Model Accuracy: 0.6339299846875237
# Labels:  ['Complaint', 'Other', 'Find My Item', 'Engagement', 'Enquiry']
# Recall: [0.80880649 0.57166948 0.26860254 0.61407249 0.14285714]
# Precison: [0.64331797 0.81294964 0.44179104 0.60759494 0.54545455]

# %% [markdown]
# ### Deep Dive on Tweets

# %%
linearsvc_classifier = linearsvc_classifier.fit(X_train, y_train)
predicted = linearsvc_classifier.predict(X_test)

missclassifiedindex= []

predictedindex = []
[predictedindex.append(i) for i,x, in enumerate(predicted.tolist())]

for i in predictedindex:
    if y_test[i] != predicted[i]:
        missclassifiedindex.append(i)
    
    #a = [missclassifiedindex.append(i) for i,x in enumerate(missclassified.tolist()) if x == True]

# %%
print('Misclassified tweets')
for x in missclassifiedindex:
    print( X_test[x])
    print('actual:',y_test[x])
    print('predicted: ',predicted_sgd[x])
    print('--------------')
# Out:
# Misclassified tweets
#
# actual: Find My Item
# predicted:  Complaint
# --------------
# sigh yes friend screenshot address label etc confirm definitely
# actual: Find My Item
# predicted:  Enquiry
# --------------
# trying trace parcel deliveri
# actual: Find My Item
# predicted:  Find My Item
# --------------
# also recipient box box 🤔
# actual: Find My Item
# predicted:  Complaint
# --------------
# maddyarrow amazing wish knew sooner haha thanks girl
# actual: Complaint
# predicted:  Other
# --------------
# tell w rdc delivery
# actual: Enquiry
# predicted:  Find My Item
# --------------
# postoffice always guaranteed delivery always insist postagedelivery require many folk b
# actual: Engagement
# predicted:  Enquiry
# --------------
# also sorting office minute awaywhen anwser phone put redelievery
# actual: Find My Item
# predicted:  Complaint
# --------------
# crash bandicoot delivered postman better fuck
# actual: Engagement
# predicted:  Complaint
# --------------
# hate tell deliver neighbour take depot million mile away
# actual: Complaint
# predicted:  Complaint
# --------------
# amazonhelp sorting office issue use rubbish delivering parcel 😡 😡
# actual: Enquiry
# predicted:  Complaint
# --------------
# text parcel ha delivered neighbour red slip neighbour given
# actual: Complaint
# predicted:  Complaint
# --------------
# good morning ha inside uk last month ha delivered problem
# actual: Find My Item
# predicted:  Complaint
# --------------
# old passport signed almost two week hasn arrived tracking information available
# actual: Complaint
# predicted:  Find My Item
# --------------
# suddenly decided delivery office ha changed mile v actual office away
# actual: Enquiry
# predicted:  Complaint
# --------------
# sorry missed card yesterday whats chance van like last tim
# actual: Enquiry
# predicted:  Complaint
# --------------
# nd class signed take longer week deliver delivered showing
# actual: Complaint
# predicted:  Find My Item
# --------------
#
# actual: Enquiry
# predicted:  Complaint
# --------------
# buy brand new ticket result really terrible customer service using courier tim
# actual: Find My Item
# predicted:  Complaint
# --------------
# great see new lgbt supporting postbox parliament stonewallcymru stonewalluk
# actual: Engagement
# predicted:  Other
# --------------
# dpduk gt
# actual: Complaint
# predicted:  Engagement
# --------------
# ordered mag subscription website nearly month edition delivered start
# actual: Complaint
# predicted:  Complaint
# --------------
# building large house converted flat flight stair cud see frm door main entrance lazy
# actual: Enquiry
# predicted:  Complaint
# --------------
# parcel due delivered last week hasnt arrived apparently tried deliver never card
# actual: Complaint
# predicted:  Find My Item
# --------------
# lost recover money con artist
# actual: Enquiry
# predicted:  Complaint
# --------------
# meggoldberger
# actual: Enquiry
# predicted:  Complaint
# --------------
# wait
# actual: Enquiry
# predicted:  Complaint
# --------------
# replied respond
# actual: Find My Item
# predicted:  Find My Item
# --------------
# pizzapat year never problem guess lucky 😎
# actual: Engagement
# predicted:  Complaint
# --------------
# reclaim cost delivery due postie misspelling name card took
# actual: Enquiry
# predicted:  Complaint
# --------------
# parcel yesterday special deliverysigned turned scam situation
# actual: Enquiry
# predicted:  Find My Item
# --------------
# special delivery guarantee deliver ireland
# actual: Enquiry
# predicted:  Find My Item
# --------------
# sukimhoward sorry send complaint might lost
# actual: Engagement
# predicted:  Complaint
# --------------
# skyhelpteam respond
# actual: Enquiry
# predicted:  Find My Item
# --------------
# srahcol sarah love chat office number available chat thanks
# actual: Engagement
# predicted:  Enquiry
# --------------
# haven received red card neighbour surname ha sign
# actual: Complaint
# predicted:  Complaint
# --------------
# explained issue image attached
# actual: Find My Item
# predicted:  Complaint
# --------------
# delivered signed name barley barley name street name
# actual: Find My Item
# predicted:  Complaint
# --------------
# icelandfoods door clearly state spam mail leaflet paper wasted post thing like
# actual: Enquiry
# predicted:  Complaint
# --------------
# iangoldenbrown emilyeavis seetickets whats point photo ticket sign envelope cancelreplace booking fee r effective system
# actual: Engagement
# predicted:  Complaint
# --------------
# noo leave house minute miss delivery ne
# actual: Find My Item
# predicted:  Complaint
# --------------
# where post man
# actual: Enquiry
# predicted:  Complaint
# --------------
#
# actual: Enquiry
# predicted:  Complaint
# --------------
# stop previous owner post coming address moved last year
# actual: Complaint
# predicted:  Enquiry
# --------------
# parcel delivered hasnt slip tracked email amazon
# actual: Complaint
# predicted:  Find My Item
# --------------
# btcare spent last week half trying sorted let time row send router cancel
# actual: Engagement
# predicted:  Complaint
# --------------
# wheres parcel meant ive dmd tracking info herd noth
# actual: Enquiry
# predicted:  Find My Item
# --------------
# haamz hamza info jl
# actual: Enquiry
# predicted:  Find My Item
# --------------
#
# actual: Engagement
# predicted:  Complaint
# --------------
# respond sn
# actual: Enquiry
# predicted:  Find My Item
# --------------
# asking time touch respect opt posting crap box
# actual: Complaint
# predicted:  Complaint
# --------------
# waiting couple delivery tuesday postman hasn road
# actual: Find My Item
# predicted:  Find My Item
# --------------
# cwugreatermanc cwuscp cwunews davewardgs cwueasternno cwuyouth cwuwestcounties tucmanchester salfordtuc mstarnorthwest fbumanchester case incitement industrial unrest
# actual: Enquiry
# predicted:  Engagement
# --------------
# postoffice rang customer service left detail waited hr follow ref recognised receipt south ken printed 😡
# actual: Find My Item
# predicted:  Complaint
# --------------
# store amazing sending replacement mannequin head asap better sort
# actual: Complaint
# predicted:  Engagement
# --------------
# tracking good news ready delivery mean delivered
# actual: Enquiry
# predicted:  Find My Item
# --------------
# waynebenskin possible stop posted afraid wayne km
# actual: Enquiry
# predicted:  Find My Item
# --------------
# victoriapeploe calm deep breath
# actual: Engagement
# predicted:  Complaint
# --------------
# well
# actual: Enquiry
# predicted:  Find My Item
# --------------
# case website updated
# actual: Find My Item
# predicted:  Complaint
# --------------
# tried missing parcel
# actual: Complaint
# predicted:  Complaint
# --------------
# stevenj upsuk thesun hasn received tracking number look matter thank amrick
# actual: Engagement
# predicted:  Find My Item
# --------------
# wish post delivery neighbour rather depot time 😩 😩 😡
# actual: Enquiry
# predicted:  Complaint
# --------------
# postoffice ☺ ️ ohh thanks jess
# actual: Find My Item
# predicted:  Enquiry
# --------------
# special agatha christie stamp collection landed major design award news dandad
# actual: Engagement
# predicted:  Engagement
# --------------
# daunorubicin cstross recipient mean
# actual: Complaint
# predicted:  Complaint
# --------------
# missort scan delivery office meanhow happenwhat thank
# actual: Enquiry
# predicted:  Find My Item
# --------------
# seemingly staff tampering mail serious stuff believe course 😋
# actual: Engagement
# predicted:  Complaint
# --------------
# slight problem thank
# actual: Find My Item
# predicted:  Complaint
# --------------
# let hasn delivered tracking_numb
# actual: Complaint
# predicted:  Find My Item
# --------------
# left schedule redeliveries online correct address ha called buzzed flat norm
# actual: Find My Item
# predicted:  Complaint
# --------------
# well done attempt actually deliver delivery slip left collect tomorrow house oupied
# actual: Complaint
# predicted:  Find My Item
# --------------
# sallysunflower make sense retain pick point new building whatever loss service
# actual: Engagement
# predicted:  Complaint
# --------------
# delivery du cane court balham
# actual: Find My Item
# predicted:  Complaint
# --------------
# parcel apparently left safe place find parcel advise
# actual: Find My Item
# predicted:  Complaint
# --------------
# particular reason started taking parcel depot mile away instead mile away fun
# actual: Enquiry
# predicted:  Complaint
# --------------
# many vehicle driven dangerously irresponsibly fast endangering vulnerable road user someth
# actual: Complaint
# predicted:  Engagement
# --------------
# sallywisebain sally thanks tweet sure friend postoffice lp
# actual: Other
# predicted:  Enquiry
# --------------
# jlabhartstar jessica sorry didn see message call interested
# actual: Engagement
# predicted:  Complaint
# --------------
# post lady rude door bell reason 😤 😤
# actual: Engagement
# predicted:  Complaint
# --------------
# jst left neighbour note case delivered parcel away last week
# actual: Enquiry
# predicted:  Complaint
# --------------
# thanks yesterday
# actual: Enquiry
# predicted:  Find My Item
# --------------
# delivers qualityofservice postalindustri
# actual: Other
# predicted:  Complaint
# --------------
# guy worried posted wednesday first class delivery hasn arrived destination
# actual: Complaint
# predicted:  Find My Item
# --------------
# never use arrogant stupid staff woking whsmith
# actual: Enquiry
# predicted:  Complaint
# --------------
# tracked order sale order ha mean
# actual: Enquiry
# predicted:  Find My Item
# --------------
# johnnyrickard everyone like 😜
# actual: Other
# predicted:  Complaint
# --------------
# worst customer service ive ever experienc
# actual: Enquiry
# predicted:  Complaint
# --------------
# seems dealing swiftly procedure customer surely instead parcel apolog
# actual: Find My Item
# predicted:  Complaint
# --------------
# supposed mail delivery nothing showed first time antrim
# actual: Find My Item
# predicted:  Complaint
# --------------
# sukitea first class mean delivery per website spec
# actual: Engagement
# predicted:  Find My Item
# --------------
#
# actual: Enquiry
# predicted:  Complaint
# --------------
# dont allowed rip tracked signed going delivered last saturday ch
# actual: Complaint
# predicted:  Find My Item
# --------------
# international packet delivered post office collect annoying
# actual: Complaint
# predicted:  Find My Item
# --------------
# possible urgent package supposed deliver yesterday
# actual: Enquiry
# predicted:  Find My Item
# --------------
# knitbritish postoffice yes irritating almost disappointed insisted standard nd class postage
# actual: Engagement
# predicted:  Complaint
# --------------
# hello long class delivery take saturday time expect waiting thx
# actual: Find My Item
# predicted:  Enquiry
# --------------
# sort missing delivery
# actual: Find My Item
# predicted:  Complaint
# --------------
# hell birthday card year old granddaughter hasn arrived posted monday getyouracttogeth
# actual: Complaint
# predicted:  Find My Item
# --------------
# dpduk better first available date redelivery tuesday
# actual: Complaint
# predicted:  Complaint
# --------------
# expecting delivery tracking delivered hasnt card left idea where
# actual: Complaint
# predicted:  Find My Item
# --------------
# arrived feel like delivered childhood though door
# actual: Engagement
# predicted:  Complaint
# --------------
# annoyed deliver parcel sorting office cant dont drive everyone block flat
# actual: Find My Item
# predicted:  Complaint
# --------------
# hello possible send tracked signed small parcel p box address usa thank
# actual: Enquiry
# predicted:  Find My Item
# --------------
# mother deaf service knock door
# actual: Enquiry
# predicted:  Complaint
# --------------
# postoffice heard find restriction website confirm stamp valid …
# actual: Complaint
# predicted:  Enquiry
# --------------
# issue leamington spa depot lost parcel bordering failing delivery nd time
# actual: Find My Item
# predicted:  Complaint
# --------------
# noticed privatisation really take piss delivery time first class arse second class take week
# actual: Find My Item
# predicted:  Engagement
# --------------
# bank informed registered dd haven made fully active thi
# actual: Complaint
# predicted:  Find My Item
# --------------
# posted signed copy book eschewed franking label cause wanted stick stamp stamp thanks amwriting
# actual: Other
# predicted:  Enquiry
# --------------
# code emailed money fucking money cd thank
# actual: Find My Item
# predicted:  Complaint
# --------------
# almost week parcel delivered snailmail
# actual: Enquiry
# predicted:  Find My Item
# --------------
# strikerplanet thanks beginning dream checked really paid £ april waitingwithbaitedbreath
# actual: Engagement
# predicted:  Complaint
# --------------
# looking forward criticaleyeuk conf call w matthew lester role cfo driving change
# actual: Engagement
# predicted:  Complaint
# --------------
# happy moment thought bbcsimonjack meant nationalising dailymailuk tracking_numberi
# actual: Engagement
# predicted:  Complaint
# --------------
# also believe delivered main address service didn leave note let
# actual: Enquiry
# predicted:  Complaint
# --------------
# aeptable paid tracked signed leaf country track appalling
# actual: Find My Item
# predicted:  Find My Item
# --------------
# file complaint called package time told something different time package
# actual: Find My Item
# predicted:  Complaint
# --------------
# staff stuck active volunteering programme helping supported volunteer involved tcvhackneygg work
# actual: Other
# predicted:  Engagement
# --------------
# wrong package return
# actual: Other
# predicted:  Find My Item
# --------------
# great service edinburgh postman brilliant wanted tweet thank
# actual: Other
# predicted:  Complaint
# --------------
# anyone
# actual: Complaint
# predicted:  Complaint
# --------------
# new house mail database seem find letterbox post mail
# actual: Complaint
# predicted:  Complaint
# --------------
# fuzzmundo fault right
# actual: Complaint
# predicted:  Complaint
# --------------
# ryantowers absolute jok
# actual: Engagement
# predicted:  Complaint
# --------------
# time moment spend bus ther
# actual: Enquiry
# predicted:  Complaint
# --------------
# parcel ha delivered signed address expensive order
# actual: Find My Item
# predicted:  Complaint
# --------------
# make complaint service given post person
# actual: Find My Item
# predicted:  Complaint
# --------------
# pls made terrible mistake
# actual: Enquiry
# predicted:  Complaint
# --------------
# really fucked custom charge mega snapback guess wait till payday 😒
# actual: Engagement
# predicted:  Complaint
# --------------
# lad
# actual: Enquiry
# predicted:  Complaint
# --------------
# parcel supposed delivered helping ref tracking_numb
# actual: Complaint
# predicted:  Find My Item
# --------------
# another parcel ha gone missing
# actual: Find My Item
# predicted:  Complaint
# --------------
# fuck
# actual: Other
# predicted:  Engagement
# --------------
# post p game class stamp post box thank
# actual: Engagement
# predicted:  Enquiry
# --------------
# enkephalin job properly sound like hassle
# actual: Engagement
# predicted:  Complaint
# --------------
# shout aswell ticket house email putting postcode address ticket
# actual: Other
# predicted:  Complaint
# --------------
# hoodies delivered wanting leave postie normally show praying miracl
# actual: Find My Item
# predicted:  Complaint
# --------------
# cut post office put counter shop come minute maybe able open post office good
# actual: Enquiry
# predicted:  Complaint
# --------------
# letting 🤔
# actual: Find My Item
# predicted:  Enquiry
# --------------
# parcel arriving select safe place delivered
# actual: Enquiry
# predicted:  Complaint
# --------------
# hackneycouncil fine didn work leave country oh life work blaming quickly suspect
# actual: Engagement
# predicted:  Complaint
# --------------
# paid custom charge supposed delivered tuesday june contact
# actual: Complaint
# predicted:  Enquiry
# --------------
# lady last week knew make reschedule delivery bloody hell going suddenly third world country
# actual: Find My Item
# predicted:  Complaint
# --------------
# pretend helpful replying tweet straight away disappear face earth like
# actual: Find My Item
# predicted:  Complaint
# --------------
# hey tracking ha
# actual: Complaint
# predicted:  Find My Item
# --------------
# someone car ha crashed front building boarded aess postman postbox
# actual: Enquiry
# predicted:  Complaint
# --------------
# disappointed follow tracking information
# actual: Find My Item
# predicted:  Enquiry
# --------------
# post man ha come special delivery come separately
# actual: Find My Item
# predicted:  Complaint
# --------------
# lose delivery jok
# actual: Find My Item
# predicted:  Complaint
# --------------
# whenever package big letterbox travel past post office designated
# actual: Enquiry
# predicted:  Complaint
# --------------
# yes rang pay grenfelltowerfire
# actual: Enquiry
# predicted:  Complaint
# --------------
# regarding issue appreciate soon thank
# actual: Find My Item
# predicted:  Complaint
# --------------
# also compensation value deleted showed progressing posting
# actual: Find My Item
# predicted:  Complaint
# --------------
# instructing postman ignore junk mail sign homeowner post opt form excelling redundant act
# actual: Engagement
# predicted:  Complaint
# --------------
# joke aess hamilton sorting office oldham parking massive queue 😡 howyoumeanttocollectaparcel
# actual: Engagement
# predicted:  Complaint
# --------------
# shadders where else work where spend time coffee shop loyalty card paid drink coffee
# actual: Engagement
# predicted:  Find My Item
# --------------
# waste thanks parcel 🙃 🙃
# actual: Find My Item
# predicted:  Complaint
# --------------
# ryanteck yeah neither asos deliver week
# actual: Complaint
# predicted:  Find My Item
# --------------
# rutlandned opposite bar sir dunc
# actual: Engagement
# predicted:  Complaint
# --------------
# moved house ordering ticket online sign delivery change address
# actual: Enquiry
# predicted:  Find My Item
# --------------
# important mail checked ups website last new york arrived usa
# actual: Enquiry
# predicted:  Find My Item
# --------------
# confirm working
# actual: Enquiry
# predicted:  Find My Item
# --------------
# geoffsmerrick coming
# actual: Enquiry
# predicted:  Find My Item
# --------------
# anyone waive charge postage manchester bee sock good cause
# actual: Engagement
# predicted:  Enquiry
# --------------
# parcel ha rejected
# actual: Enquiry
# predicted:  Complaint
# --------------
# going staff rudeness poor aess arrangement yeovil
# actual: Engagement
# predicted:  Complaint
# --------------
# stopped van asked nothing email confirmation redelivery ref
# actual: Enquiry
# predicted:  Complaint
# --------------
# standard international service told lost lost recipient left uk
# actual: Find My Item
# predicted:  Complaint
# --------------
# revolutapp chatting someone online via app continue thank
# actual: Complaint
# predicted:  Engagement
# --------------
# customer service telephone number cannot find onlin
# actual: Enquiry
# predicted:  Complaint
# --------------
# photo block packaged collected london jersey exotic location thank always time 💪 🏼 👍 🏻
# actual: Enquiry
# predicted:  Complaint
# --------------
# sale order mean 😩 parcel annoy
# actual: Find My Item
# predicted:  Find My Item
# --------------
# charging pick wedding invite post office paid postage
# actual: Complaint
# predicted:  Complaint
# --------------
# ha parcel diverted kingswood reply
# actual: Find My Item
# predicted:  Find My Item
# --------------
# virtuarch hey james mind regarding mail charge looking extra charge ourring
# actual: Engagement
# predicted:  Complaint
# --------------
# shout wee guy personally made sure delivery b holiday tomorrow ❤ ️ ❤ ️ ❤ ️ ❤ ️ ❤ ️
# actual: Other
# predicted:  Find My Item
# --------------
# good news progressing network posted via mail signed waiting refund
# actual: Complaint
# predicted:  Find My Item
# --------------
# protocol making official complaint plea
# actual: Enquiry
# predicted:  Complaint
# --------------
# another waiting parcel delivered address lived year dissatisfi
# actual: Enquiry
# predicted:  Complaint
# --------------
# cost £ arsehole delivered neighbor signature
# actual: Find My Item
# predicted:  Complaint
# --------------
# received something card address appears mine name card wrong name flat number
# actual: Enquiry
# predicted:  Complaint
# --------------
# man lost bludclart post fix
# actual: Find My Item
# predicted:  Complaint
# --------------
# thank whoever found wallet put post box thanks returning 👍 🏻
# actual: Other
# predicted:  Complaint
# --------------
# nadeemmazhar dhlpaket better changed delivery time instead package leiden pickup place delft delivery
# actual: Engagement
# predicted:  Find My Item
# --------------
# postoffice
# actual: Complaint
# predicted:  Enquiry
# --------------
# 🙏 🏽
# actual: Find My Item
# predicted:  Complaint
# --------------
# iamhannahburns done multiple time
# actual: Engagement
# predicted:  Complaint
# --------------
# 😭
# actual: Find My Item
# predicted:  Complaint
# --------------
# crash bandicoot didn arrive screw class post yesterday morning delivery useless
# actual: Enquiry
# predicted:  Complaint
# --------------
# lornebalfe thought postman v casual dress 😳
# actual: Enquiry
# predicted:  Complaint
# --------------
# submitted lost claim didn confirmation email sure gone shall submit
# actual: Find My Item
# predicted:  Complaint
# --------------
# myeesharona serious taken bank card id
# actual: Engagement
# predicted:  Complaint
# --------------
# tracking_number worry strangely without post load time 🤔
# actual: Enquiry
# predicted:  Complaint
# --------------
# parcel miss
# actual: Complaint
# predicted:  Find My Item
# --------------
# drnahil suzieszabo partyharty lasancmt yes registered expensive fucking junckereu eucopresident 😂
# actual: Engagement
# predicted:  Complaint
# --------------
# parklikeamoron parklikeatwat week winner parking like ct parklikeaahole
# actual: Engagement
# predicted:  Complaint
# --------------
# used special delivery guaranteed delivery address wareham delivered
# actual: Complaint
# predicted:  Find My Item
# --------------
# furious paid £ delivery told six collection delivery made
# actual: Find My Item
# predicted:  Complaint
# --------------
# lauraandmrb haven delivered holiday collar either last saturday utter 💩
# actual: Complaint
# predicted:  Find My Item
# --------------
# order delivered right address delivery man told wrong flat right flat
# actual: Enquiry
# predicted:  Complaint
# --------------
# actionfrauduk made report metpoliceuk intercept parcel scammer pick depot
# actual: Find My Item
# predicted:  Complaint
# --------------
# birdman amazonuk dpduk reason ill moment made house past week living rural location bookshop
# actual: Find My Item
# predicted:  Complaint
# --------------
# lost parcel delivered last week 😡 😡
# actual: Complaint
# predicted:  Find My Item
# --------------
# main road sutton hone stopped w kitten sadly died sweet
# actual: Other
# predicted:  Complaint
# --------------
# waiting respons
# actual: Find My Item
# predicted:  Find My Item
# --------------
# love directmail campaign stats suggest consumer right message
# actual: Engagement
# predicted:  Find My Item
# --------------
# lewisbaker perfectly honest postman uniform talking piss working dressing gown
# actual: Engagement
# predicted:  Complaint
# --------------
# screw waited around package wale rush wedding dont dress 😡
# actual: Find My Item
# predicted:  Complaint
# --------------
# waited morning parcel turned text tried deliver collect
# actual: Complaint
# predicted:  Find My Item
# --------------
# went track parcel morning website state recognise tracking number worked
# actual: Complaint
# predicted:  Find My Item
# --------------
# fucking worst
# actual: Find My Item
# predicted:  Complaint
# --------------
#
# actual: Find My Item
# predicted:  Complaint
# --------------
# mail delivery two hp tyler green problem
# actual: Enquiry
# predicted:  Complaint
# --------------
# hello query
# actual: Enquiry
# predicted:  Find My Item
# --------------
# application first provisional license passport dvla haven received passport
# actual: Find My Item
# predicted:  Complaint
# --------------
# found middle road walk home house around corner posted
# actual: Engagement
# predicted:  Complaint
# --------------
# signed package went previous address london office allow someone pick absence
# actual: Find My Item
# predicted:  Complaint
# --------------
# look like suffered loosing parcel post claim sir
# actual: Find My Item
# predicted:  Complaint
# --------------
# mongreladam where sender hasn paid enough postage pay guarantee going junk mail
# actual: Engagement
# predicted:  Complaint
# --------------
# johnohopkins sorchaholloway plymouth electoralcommuk look like problem newcastle lyme twenty currently civic centre phone ringing const marginal seat
# actual: Enquiry
# predicted:  Engagement
# --------------
# put delilah naming invite post nd class yesterday good job
# actual: Other
# predicted:  Complaint
# --------------
# hasbean okay two caffeine
# actual: Find My Item
# predicted:  Complaint
# --------------
# customer service absolutely outstanding best customer service ever experienced well done
# actual: Other
# predicted:  Complaint
# --------------
# email parcel ha delivered nominated safe place red card left parcel seen
# actual: Complaint
# predicted:  Find My Item
# --------------
# ask take something birmingham mail centre smethwicks like far apart dx
# actual: Enquiry
# predicted:  Complaint
# --------------
# marina going tomorrow wanted see worth wasting time thank though ✨
# actual: Enquiry
# predicted:  Complaint
# --------------
# dont sad right 🙁
# actual: Find My Item
# predicted:  Complaint
# --------------
# talk service downgrade final weekday collection used year yesterday cwunews
# actual: Complaint
# predicted:  Engagement
# --------------
# delivered package someone else going deliver
# actual: Enquiry
# predicted:  Complaint
# --------------
# technical difficulty going website unable tracking
# actual: Complaint
# predicted:  Enquiry
# --------------
# bethtinkerbell fail
# actual: Engagement
# predicted:  Complaint
# --------------
#
# actual: Engagement
# predicted:  Complaint
# --------------
# fucking lastyoungrenegade cd arrive ill sur
# actual: Find My Item
# predicted:  Complaint
# --------------
# live chat open urgent enquiri
# actual: Find My Item
# predicted:  Complaint
# --------------
# tracking_number delivered tracking show peterborough 😟
# actual: Complaint
# predicted:  Find My Item
# --------------
# andybrussell promised last year adopted code keep coming soon scammer trying luck
# actual: Engagement
# predicted:  Complaint
# --------------
# annafillnerova sound like didn bring due closed sat arrive todaytomorrow
# actual: Find My Item
# predicted:  Complaint
# --------------
# actually reply emailed week nothing parcel £ fabric gone missing thanks
# actual: Complaint
# predicted:  Complaint
# --------------
# stupid almost unbelievable sold lost address paperwork
# actual: Enquiry
# predicted:  Complaint
# --------------
# made list delivering wrasslinfan parcel jericho top sort iamjericho
# actual: Engagement
# predicted:  Complaint
# --------------
# send nd class chance delivered last lost post
# actual: Complaint
# predicted:  Find My Item
# --------------
# aess property lazy deliverer bothered looking properly address card left royalfail
# actual: Find My Item
# predicted:  Complaint
# --------------
# morphrv worse might delivered yodel entirely different street 🙂
# actual: Engagement
# predicted:  Complaint
# --------------
# cancel post redirection renewal refund ha used renewal till
# actual: Enquiry
# predicted:  Complaint
# --------------
# scottdowie address file jr
# actual: Find My Item
# predicted:  Complaint
# --------------
# read received birthday cupcake package fragile written
# actual: Enquiry
# predicted:  Complaint
# --------------
# tommytav iangoldenbrown emilyeavis seetickets someone else ha signed ticket seetickets refusing police involved theft
# actual: Engagement
# predicted:  Complaint
# --------------
# missy empire kitty empire journalist
# actual: Enquiry
# predicted:  Complaint
# --------------
# point posting first class arrive two
# actual: Enquiry
# predicted:  Complaint
# --------------
#
# actual: Find My Item
# predicted:  Complaint
# --------------
# recorded delivery ha gone missing really speak someone
# actual: Find My Item
# predicted:  Complaint
# --------------
# rang customer service left detail waited hr follow ref recognised receipt south ken printed
# actual: Find My Item
# predicted:  Complaint
# --------------
# never see imm
# actual: Complaint
# predicted:  Complaint
# --------------
# parcel status showing post office where posted ha wednesday idea
# actual: Enquiry
# predicted:  Find My Item
# --------------
# requested new build address added told display online showing number
# actual: Complaint
# predicted:  Enquiry
# --------------
# congratulation mail stamp design competition finalista huge achievement entry 🎖 👏 🌟
# actual: Engagement
# predicted:  Engagement
# --------------
# choose saturday delivery haven delivered delivery office excuse
# actual: Find My Item
# predicted:  Find My Item
# --------------
# try avoid passport take long fuck job
# actual: Enquiry
# predicted:  Complaint
# --------------
# sell smaller denomination make difference lovely commemorative class wanted use
# actual: Complaint
# predicted:  Complaint
# --------------
# applied redelivery tues parcel deliver confirmation email sign parcel
# actual: Enquiry
# predicted:  Complaint
# --------------
# postorifice stone dwp
# actual: Engagement
# predicted:  Complaint
# --------------
# zorasuleman sure ha nicked
# actual: Engagement
# predicted:  Complaint
# --------------
# sorry missed card yesterday whats chance van like last tim
# actual: Enquiry
# predicted:  Complaint
# --------------
# andyplant happened posted somewhere else didn leave note
# actual: Engagement
# predicted:  Complaint
# --------------
# hurry bruh
# actual: Enquiry
# predicted:  Find My Item
# --------------
# message presume hoax
# actual: Enquiry
# predicted:  Complaint
# --------------
# scammed seller ebay parcel nigeria cancel
# actual: Find My Item
# predicted:  Find My Item
# --------------
# trust amazonhelp mess pre order 🙄
# actual: Find My Item
# predicted:  Complaint
# --------------
# ritaonwurah registeredinsured mail nigeria delivered someone pls
# actual: Find My Item
# predicted:  Complaint
# --------------
# mickyjayuk normally make official complaint however last time unofficially stopped post two week
# actual: Engagement
# predicted:  Complaint
# --------------
# tescobankhelp replacing card left without week replacement lost ever heard recorded delivery
# actual: Engagement
# predicted:  Complaint
# --------------
# hidden fee fuck
# actual: Enquiry
# predicted:  Engagement
# --------------
# problem tracking signed package returned postman wrong address website delivered
# actual: Find My Item
# predicted:  Complaint
# --------------
# post miss part address
# actual: Enquiry
# predicted:  Complaint
# --------------
# jackmanchester jack sorry missed looking redelivered post office branch currently
# actual: Enquiry
# predicted:  Complaint
# --------------
# guy long direct message take reply issu
# actual: Enquiry
# predicted:  Find My Item
# --------------
# advise contact report postbox urgent repair many thanks
# actual: Complaint
# predicted:  Enquiry
# --------------
# disgusted service provide parcel ordered charity ha gone missing replace 😡
# actual: Find My Item
# predicted:  Complaint
# --------------
# myeesharona ahh guess problem actual id photograph frustrating
# actual: Engagement
# predicted:  Complaint
# --------------
# paid delivered yesterday never arrived reference number advise
# actual: Complaint
# predicted:  Find My Item
# --------------
# heelp
# actual: Enquiry
# predicted:  Complaint
# --------------
# konichiwakitty interesting never knew rm sunday delivery
# actual: Engagement
# predicted:  Complaint
# --------------
# parcel ready collection tomorrow circled confused
# actual: Find My Item
# predicted:  Find My Item
# --------------
# tell ill package plea
# actual: Enquiry
# predicted:  Find My Item
# --------------
# going guy moment took first class package arrive
# actual: Complaint
# predicted:  Find My Item
# --------------
# possible let postman leave somewhere
# actual: Enquiry
# predicted:  Complaint
# --------------
# dear new click drop service look great except aept post code like lloyd bank bx lt oversight
# actual: Enquiry
# predicted:  Complaint
# --------------
# expecting package home time pick mail office arrange someth
# actual: Enquiry
# predicted:  Complaint
# --------------
# shipping time londen heathrow amsterdam
# actual: Enquiry
# predicted:  Find My Item
# --------------
# nobody done anything sort 🙂
# actual: Find My Item
# predicted:  Complaint
# --------------
#
# actual: Find My Item
# predicted:  Complaint
# --------------
# email parcel ha delivered house haven received
# actual: Complaint
# predicted:  Find My Item
# --------------
# jomillerdonny mydoncaster mydoncaster jomillerdonny shame victim latest able vote eh chokingonyourfum
# actual: Complaint
# predicted:  Engagement
# --------------
# something address mail signed leave slip postbox deliver
# actual: Complaint
# predicted:  Complaint
# --------------
# nothing joke weddingplan
# actual: Enquiry
# predicted:  Complaint
# --------------
# dear talk freaking human ffs
# actual: Enquiry
# predicted:  Complaint
# --------------
# onehundredband vinyl stuck sorting office co seems dont leave parcel neighbour anymore 😠
# actual: Engagement
# predicted:  Complaint
# --------------
# wanna ask sheffield mail center mean delivered
# actual: Complaint
# predicted:  Find My Item
# --------------
# friend philippine claim dont tracking number
# actual: Enquiry
# predicted:  Find My Item
# --------------
# answer like where thanks
# actual: Complaint
# predicted:  Find My Item
# --------------
# strikerplanet starting wonder received
# actual: Engagement
# predicted:  Complaint
# --------------
# evasive w answer either system parcel addressed wrong house system
# actual: Find My Item
# predicted:  Complaint
# --------------
# bbcsoutheast hunt perpetrator buy himher apple ha made saturday 😀 🍏 🍎 🍏 🍎 😀
# actual: Engagement
# predicted:  Find My Item
# --------------
# tracking missed parcel yesterday left card card tracking num tracking_numb
# actual: Complaint
# predicted:  Find My Item
# --------------
# page report two jumper graze box without speaking anyone 😂 well done postie
# actual: Engagement
# predicted:  Complaint
# --------------
# pboxall yes exactly annoying thank repli
# actual: Engagement
# predicted:  Complaint
# --------------
# reference number parcel receiving guy service used tracking_number class
# actual: Enquiry
# predicted:  Find My Item
# --------------
# big lady post office super cheery friendly though ikea bag full track sign parcel 👏
# actual: Other
# predicted:  Find My Item
# --------------
# spoken linda tel line brilliant real credit friendly efficient manner proper customer service
# actual: Other
# predicted:  Complaint
# --------------
# apparently tracked parcel delivered neighbour postman failed let
# actual: Find My Item
# predicted:  Complaint
# --------------
# leocookman went vacation 💌
# actual: Engagement
# predicted:  Complaint
# --------------
# billmacroofing claim lost ask claim deny claim like post
# actual: Find My Item
# predicted:  Complaint
# --------------
# tidying desk drawer found book class stamp xmas range use
# actual: Enquiry
# predicted:  Complaint
# --------------
# depot open impossible job missed delivery
# actual: Complaint
# predicted:  Complaint
# --------------
# hell tried various browser whole thing simply work
# actual: Find My Item
# predicted:  Complaint
# --------------
# mean
# actual: Find My Item
# predicted:  Find My Item
# --------------
# thanks leaving another something card house waiting delivery 🙃 🙃 super cool
# actual: Complaint
# predicted:  Complaint
# --------------
#
# actual: Find My Item
# predicted:  Complaint
# --------------
# moonpiguk really hope placed order personal mug freind put wrong pcode address nearly week ☹ ️
# actual: Find My Item
# predicted:  Complaint
# --------------
# thing ordered twice moonpiguk delivered absolute disgusted servic
# actual: Find My Item
# predicted:  Complaint
# --------------
# waiting response respond immedi
# actual: Complaint
# predicted:  Find My Item
# --------------
# posties washington always happy delivery card 😄
# actual: Other
# predicted:  Complaint
# --------------
# cost send enough bubblewrap majorca roll camilla
# actual: Engagement
# predicted:  Complaint
# --------------
# p door left neighbour didn knocked neighbour parcel
# actual: Find My Item
# predicted:  Complaint
# --------------
# itsamy 👊
# actual: Engagement
# predicted:  Complaint
# --------------
# disgusted delivery private confidential recieved like
# actual: Enquiry
# predicted:  Complaint
# --------------
# novaalexxander morning nova glad see delivered saturday sorry concern caused
# actual: Find My Item
# predicted:  Complaint
# --------------
# charge send oversized thanj
# actual: Enquiry
# predicted:  Enquiry
# --------------
# keep telling reported scammer police thank assisting cyber criminal 👌 🏼
# actual: Find My Item
# predicted:  Complaint
# --------------
# lovelymulberry thought paid extra tracked clearly
# actual: Find My Item
# predicted:  Complaint
# --------------
# tracking number tracking_number thank
# actual: Other
# predicted:  Find My Item
# --------------
# littlewishhire sorry ha happened tracking number look mt
# actual: Complaint
# predicted:  Find My Item
# --------------
# great service jeff steve morning dl na
# actual: Other
# predicted:  Complaint
# --------------
# postcode finder problem lot odd result returned touch premium
# actual: Enquiry
# predicted:  Complaint
# --------------
# paper posted via class signed march early morning till arrived
# actual: Complaint
# predicted:  Find My Item
# --------------
# swear god bitch gotta shit together time lost parcel desk djdjekfkfomskc
# actual: Engagement
# predicted:  Complaint
# --------------
# fact asos text delivering make happy hope continues myhermes
# actual: Other
# predicted:  Complaint
# --------------
# text house right red card either parcel
# actual: Find My Item
# predicted:  Complaint
# --------------
# find parcel delivered tuesday driver left card parcel signed legible
# actual: Find My Item
# predicted:  Complaint
# --------------
# wanna find pls package arr
# actual: Enquiry
# predicted:  Find My Item
# --------------
# right lazy lazy toad
# actual: Engagement
# predicted:  Complaint
# --------------
# delivery tracking_number issue area
# actual: Complaint
# predicted:  Find My Item
# --------------
# mean collect package
# actual: Find My Item
# predicted:  Find My Item
# --------------
# urgent pick skip middle man
# actual: Find My Item
# predicted:  Complaint
# --------------
# respond left
# actual: Find My Item
# predicted:  Find My Item
# --------------
# davidaslindsay mail enthusiast helped starting delivering post
# actual: Enquiry
# predicted:  Complaint
# --------------
# take least package wk neighbour try mine
# actual: Enquiry
# predicted:  Complaint
# --------------
# declined redirection renewal payment time bank security call tell processed pay
# actual: Enquiry
# predicted:  Complaint
# --------------
# non delivery text without coming door actual fuck bothered
# actual: Complaint
# predicted:  Complaint
# --------------
# droylsden office open collect work unable collect morn
# actual: Complaint
# predicted:  Complaint
# --------------
# adrafa postman rate
# actual: Engagement
# predicted:  Complaint
# --------------
# tell special able perfume send perth au melbourne au plea
# actual: Enquiry
# predicted:  Find My Item
# --------------
# email parcel delivered yesterday nothing come came abroad
# actual: Complaint
# predicted:  Find My Item
# --------------
# long signed signature kept website delivery made
# actual: Enquiry
# predicted:  Complaint
# --------------
# pulpjohnfiction always serious lol nah stuff
# actual: Engagement
# predicted:  Complaint
# --------------
# look vacancy website
# actual: Engagement
# predicted:  Complaint
# --------------
# received sorry missed card come pick working possible
# actual: Enquiry
# predicted:  Complaint
# --------------
# ordered something gone track order mean ha delivered
# actual: Enquiry
# predicted:  Find My Item
# --------------
# itsamy
# actual: Engagement
# predicted:  Complaint
# --------------
# parcel australia via mail forgotten attach cn form forward somehow
# actual: Enquiry
# predicted:  Find My Item
# --------------
# love take collect delivery office
# actual: Complaint
# predicted:  Enquiry
# --------------
# 🙏 🏻 xo 📦
# actual: Find My Item
# predicted:  Complaint
# --------------
#
# actual: Find My Item
# predicted:  Complaint
# --------------
# mail usa international tracked signed tuesday ha updated wednesday normal
# actual: Enquiry
# predicted:  Find My Item
# --------------
# ameslouisex guarantee arrive soon jr
# actual: Find My Item
# predicted:  Complaint
# --------------
# delivery thank
# actual: Enquiry
# predicted:  Find My Item
# --------------
# hello tell claim number coming along many thank
# actual: Enquiry
# predicted:  Find My Item
# --------------
# trying work delivered package yesterday
# actual: Complaint
# predicted:  Find My Item
# --------------
# disappoint shocking servic
# actual: Enquiry
# predicted:  Complaint
# --------------
# recieved address stokeontrent live salford similar postcode area
# actual: Complaint
# predicted:  Enquiry
# --------------
# wait parcel dog bark like crazy someone knock attempted deliver tracking
# actual: Complaint
# predicted:  Find My Item
# --------------
# friend claiming paid correct postage put first class stamp happi
# actual: Complaint
# predicted:  Enquiry
# --------------
# sort ur shit
# actual: Other
# predicted:  Complaint
# --------------
# sumkerrie summer km
# actual: Enquiry
# predicted:  Complaint
# --------------
# bound canada nothing showing rm site canada post uk gblala
# actual: Find My Item
# predicted:  Complaint
# --------------
# something posted first class stamp received post
# actual: Complaint
# predicted:  Enquiry
# --------------
# fucked somehow phone ha disappeared mail
# actual: Find My Item
# predicted:  Complaint
# --------------
# pay £ mail affected grenfelltowerfire daughter operation date
# actual: Enquiry
# predicted:  Complaint
# --------------
# waiting parcel time like clue whats happening track tracking_numb
# actual: Complaint
# predicted:  Find My Item
# --------------
# postoffice problem thanks actually replying mail chance replynot hang great
# actual: Find My Item
# predicted:  Complaint
# --------------
# geekanoids verynetwork pdtalkintech bkletchy cazualluk tldtoday literally joke 😂
# actual: Complaint
# predicted:  Engagement
# --------------
# response
# actual: Enquiry
# predicted:  Complaint
# --------------
# kaylacjenkins ugh sorry kayla horrible feeling dog mom another
# actual: Engagement
# predicted:  Complaint
# --------------
# seems lost package mine collection depot hope take responsibility never found
# actual: Find My Item
# predicted:  Complaint
# --------------
# email mail office plea
# actual: Enquiry
# predicted:  Find My Item
# --------------
# andyplant probably new guy
# actual: Engagement
# predicted:  Complaint
# --------------
# carlaah sorry delay service used trackable lp
# actual: Complaint
# predicted:  Complaint
# --------------
# average time period international standard parcel queensland australia seller posted june
# actual: Enquiry
# predicted:  Find My Item
# --------------
# url form report postcode address file error
# actual: Enquiry
# predicted:  Complaint
# --------------
# tracking_number fuming yeezi
# actual: Engagement
# predicted:  Find My Item
# --------------
# helloo greecegramcom lovely connect twitterverse thanks follow gt gt
# actual: Other
# predicted:  Complaint
# --------------
# aeptable
# actual: Engagement
# predicted:  Complaint
# --------------
# holiday ticket delivered address away however sign kept
# actual: Enquiry
# predicted:  Find My Item
# --------------
# also pod recorded delivered wtf
# actual: Enquiry
# predicted:  Complaint
# --------------
# rubbish service postman also lied wrote came calling card wasted gig ticket disgusting servic
# actual: Find My Item
# predicted:  Complaint
# --------------
# fucking shit hate fucking every time delivery fuck fucking bullshit
# actual: Engagement
# predicted:  Complaint
# --------------
# becoming regular problem sick wasting indoor waiting package never arrive
# actual: Find My Item
# predicted:  Complaint
# --------------
# beckybedbug
# actual: Engagement
# predicted:  Complaint
# --------------
# waiting response location £ paid insure prof requir
# actual: Complaint
# predicted:  Complaint
# --------------
# seems like many issue automated system complaint give beepbeepbeep every time
# actual: Enquiry
# predicted:  Complaint
# --------------
# tracking number ur website delivered working neighbor given
# actual: Complaint
# predicted:  Find My Item
# --------------
# postoffice proof posting proof
# actual: Enquiry
# predicted:  Complaint
# --------------
# tracking delivered neighbour neighbour taken anything card take
# actual: Find My Item
# predicted:  Complaint
# --------------
# ha parcel destined united arab emirate gone new york bouncing around new jersey
# actual: Complaint
# predicted:  Find My Item
# --------------
# reply direct messag
# actual: Complaint
# predicted:  Find My Item
# --------------
# state fucking tragic service
# actual: Find My Item
# predicted:  Complaint
# --------------
# lost tracked parcel mine make claim sender recipient make complaint
# actual: Complaint
# predicted:  Complaint
# --------------
# package delivered northern ireland address send put ireland package receive
# actual: Enquiry
# predicted:  Find My Item
# --------------
# currently desk relying deliver desk tomorrow otherwise im fucked xd
# actual: Other
# predicted:  Complaint
# --------------
# where parcel called line offer investigation option deliver parcel apparently
# actual: Complaint
# predicted:  Find My Item
# --------------
# going depot il collect
# actual: Find My Item
# predicted:  Complaint
# --------------
# change postie year post new leaf someone else postbox 👎 😡
# actual: Complaint
# predicted:  Complaint
# --------------
# small parcel usa using online tool expected pay £ charged £
# actual: Engagement
# predicted:  Complaint
# --------------
# especially someone parcel time place nd signed delivered
# actual: Find My Item
# predicted:  Complaint
# --------------
# parcel ha arrived week compensation parcel website unhelpful
# actual: Find My Item
# predicted:  Complaint
# --------------
# look forward taking finest sunday comeontheblues p thanks tweet casey 💙 👍
# actual: Engagement
# predicted:  Complaint
# --------------
# asosheretohelp return ball court status return
# actual: Find My Item
# predicted:  Find My Item
# --------------
# posted something yesterday proof purchase ha completely different building number wrote address
# actual: Enquiry
# predicted:  Complaint
# --------------
# parcelforce maybe parcelforce decipher scribble mean
# actual: Complaint
# predicted:  Find My Item
# --------------
# address idea
# actual: Complaint
# predicted:  Complaint
# --------------
# answer quest
# actual: Find My Item
# predicted:  Complaint
# --------------
# markmcewan nice touch passed tweet rm ha anyone new case replace
# actual: Engagement
# predicted:  Enquiry
# --------------
# ineffeciency stunning always literally queing door leytonstone delevery offic
# actual: Enquiry
# predicted:  Complaint
# --------------
# lbqblog reapply kept card registered address kept refusing week
# actual: Engagement
# predicted:  Complaint
# --------------
# stamp valid postage anyone value american
# actual: Complaint
# predicted:  Enquiry
# --------------
# everything crossed seetickets sort cockup leave bonny lad without glastofest ticket
# actual: Find My Item
# predicted:  Complaint
# --------------
# postoffice really long something underpaid take receive card notifying al
# actual: Enquiry
# predicted:  Complaint
# --------------
# postoffice round circle
# actual: Find My Item
# predicted:  Complaint
# --------------
# tolerantbrother sorry experiencing technical issue resolved apologise inconvenience caused
# actual: Enquiry
# predicted:  Complaint
# --------------
# tell hasn paid full postage etc choose pay remaining postage
# actual: Enquiry
# predicted:  Complaint
# --------------
# obviously death wish revamped online postage made clumsy unusable
# actual: Complaint
# predicted:  Complaint
# --------------
# postoffice thanks replying stephen
# actual: Find My Item
# predicted:  Engagement
# --------------
# lenniewratten shipped uk first class signed described site signature required tuesday
# actual: Engagement
# predicted:  Find My Item
# --------------
# 🇩 🇪
# actual: Find My Item
# predicted:  Complaint
# --------------
# contact compensation
# actual: Enquiry
# predicted:  Complaint
# --------------
# news lie broken promise told mail year ive ther
# actual: Engagement
# predicted:  Complaint
# --------------
#
# actual: Enquiry
# predicted:  Complaint
# --------------
# delivery history house address im every morning normally delivers decided leav
# actual: Complaint
# predicted:  Complaint
# --------------
# post office ha computer depot cleared
# actual: Find My Item
# predicted:  Complaint
# --------------
# tracking tracking_number delivery address
# actual: Enquiry
# predicted:  Find My Item
# --------------
# email delivered neighbour card telling 😕
# actual: Find My Item
# predicted:  Complaint
# --------------
# thank put claim investigation business going large confirmed promised last year
# actual: Find My Item
# predicted:  Complaint
# --------------
# englishheritage thanks caring havent bothered reply profession
# actual: Enquiry
# predicted:  Complaint
# --------------
# order track number website pretty confusing 😟 really appreciate 🙏
# actual: Complaint
# predicted:  Find My Item
# --------------
# ...
# actual: Complaint
# predicted:  Complaint
# --------------
# sophierussell ref tracking_number
# actual: Engagement
# predicted:  Find My Item
# --------------
# away weekend guess parcel pocket
# actual: Enquiry
# predicted:  Complaint
# --------------
# received postal ballot conplaint canno filed detail conservative dailyexpressuk
# actual: Complaint
# predicted:  Engagement
# --------------
# contact postal service country
# actual: Find My Item
# predicted:  Complaint
# --------------
# package deliv
# actual: Enquiry
# predicted:  Find My Item
# --------------
# van allowed bus lane keep seeing liverpool seems bit scammy
# actual: Enquiry
# predicted:  Complaint
# --------------
# asosheretohelp ha scanned tracking code office claim enough happy asosheretohelp scanned
# actual: Engagement
# predicted:  Find My Item
# --------------
# ordered last week posted wednesday hasn arrived something card
# actual: Complaint
# predicted:  Find My Item
# --------------
# believe mail ha thief really annoyed upset saw someone else tweet similar mine
# actual: Engagement
# predicted:  Complaint
# --------------
# postoffice oops sorry
# actual: Enquiry
# predicted:  Complaint
# --------------
# write gorgeous dog like prob bill dog pay bill
# actual: Enquiry
# predicted:  Complaint
# --------------
# mean parcel ha delivered haven left message where
# actual: Complaint
# predicted:  Find My Item
# --------------
# oliviapittam noo 😮 😮
# actual: Engagement
# predicted:  Complaint
# --------------
# chloearch believe 😞
# actual: Complaint
# predicted:  Engagement
# --------------
# peetbart peter sorry kept waiting confirm referring post office branch separ
# actual: Complaint
# predicted:  Find My Item
# --------------
# signed inside blank paper trace sender plz concerned postalscam tq
# actual: Enquiry
# predicted:  Complaint
# --------------
# signed package posted nobody signed
# actual: Find My Item
# predicted:  Complaint
# --------------
# paid tracked service parcel force lady mail ha put wrong postcode parcel
# actual: Enquiry
# predicted:  Find My Item
# --------------
# dear three refunded cheque rm gone missing post awaiting fourth month
# actual: Find My Item
# predicted:  Complaint
# --------------
# ridiculous guaranteed rate telling first class guaranteed course
# actual: Find My Item
# predicted:  Complaint
# --------------
# sold online believed lost ha turned sale ebay bought auction lost
# actual: Enquiry
# predicted:  Find My Item
# --------------
# joke evan attempted deliver parcel
# actual: Find My Item
# predicted:  Complaint
# --------------
# post nd class signed hasn arrived tracking tracking_number tell delay
# actual: Complaint
# predicted:  Find My Item
# --------------
# themgee gi postcode able establish correct area delivery delayed lp
# actual: Find My Item
# predicted:  Complaint
# --------------
# thanks open work morning trip sorting office witnessing happy banter colleague
# actual: Other
# predicted:  Complaint
# --------------
# angieh hell writes date yymmdd mean american
# actual: Engagement
# predicted:  Find My Item
# --------------
# fed two hanging around parcel hasn come supposedly delivery
# actual: Find My Item
# predicted:  Complaint
# --------------
# lauramalarkey that's pretty low …
# actual: Engagement
# predicted:  Complaint
# --------------
# chrishammondha chris closing time delivery window tracking_number often arrive time lp
# actual: Complaint
# predicted:  Find My Item
# --------------
# find hard believe card door ha door
# actual: Find My Item
# predicted:  Complaint
# --------------
# drnahil suzieszabo partyharty lasancmt giving birth take month exiting eu take email registered using
# actual: Engagement
# predicted:  Complaint
# --------------
# niccorry thanks making aware killer cover version better original anything
# actual: Complaint
# predicted:  Complaint
# --------------
# see trekking depot miss redelivered monday busy week hence grr
# actual: Complaint
# predicted:  Find My Item
# --------------
# ticketmaster didn change address redirection old address signed redirected
# actual: Enquiry
# predicted:  Complaint
# --------------
# many retweets follow
# actual: Engagement
# predicted:  Enquiry
# --------------
# dog awareness week let look post men woman keeping dog control staff keep great job
# actual: Engagement
# predicted:  Complaint
# --------------
# bunch trollop receive email delivered sign slip charged £
# actual: Complaint
# predicted:  Find My Item
# --------------
# xflowerstarx postoffice ordered processed picked aount detail email team info
# actual: Engagement
# predicted:  Find My Item
# --------------
# fantastic see company like 👌 🏼
# actual: Engagement
# predicted:  Complaint
# --------------
# egar parcel long take tracked sign parcel arrive plea
# actual: Enquiry
# predicted:  Find My Item
# --------------
# 😀 possible stop parcel delivered ebay buyer wrong address used signed mon jul
# actual: Enquiry
# predicted:  Complaint
# --------------
# ignoring fam
# actual: Find My Item
# predicted:  Complaint
# --------------
# mtracking_number try ask
# actual: Engagement
# predicted:  Complaint
# --------------
# lost parcel parcel attempted delivery yesterday gone collect find sorting office
# actual: Complaint
# predicted:  Find My Item
# --------------
# wonder lot struggling letterbox whole birmingham 👍 🏻
# actual: Enquiry
# predicted:  Complaint
# --------------
# whats best service send small parcel kg worth £ dont spend
# actual: Enquiry
# predicted:  Complaint
# --------------
# follow regarding working delivery unhappy wish discus
# actual: Complaint
# predicted:  Enquiry
# --------------
# card post office delivered wed advising fee pay paid promptly wed sat where
# actual: Complaint
# predicted:  Complaint
# --------------
# repli
# actual: Complaint
# predicted:  Complaint
# --------------
# mr bean stuck post box 😂 👍
# actual: Engagement
# predicted:  Complaint
# --------------
# leave signed note post allowed leave neighbour rather take sorting office
# actual: Enquiry
# predicted:  Complaint
# --------------
# ammii come thruu
# actual: Engagement
# predicted:  Complaint
# --------------
# happen collect mail collect post week maybe week remember set
# actual: Enquiry
# predicted:  Complaint
# --------------
# rudest customer service self service counter hilldene postoffice lazy
# actual: Engagement
# predicted:  Complaint
# --------------
# derbyspolice royalmintuk advise neighbor signed parcel denying
# actual: Complaint
# predicted:  Find My Item
# --------------
# online reference number tried deliver slip left letterbox
# actual: Complaint
# predicted:  Find My Item
# --------------
# two meant arrive via guaranteed delivery rm tracking arrived course
# actual: Complaint
# predicted:  Find My Item
# --------------
# nicest posture always delivering b 👍 🏻 😊
# actual: Engagement
# predicted:  Complaint
# --------------
# piedalton frond didn name although call various expletive
# actual: Enquiry
# predicted:  Complaint
# --------------
# guarenteed im expecting come important
# actual: Enquiry
# predicted:  Find My Item
# --------------
# bbcbreaking idea phone line
# actual: Find My Item
# predicted:  Complaint
# --------------
# almost certain also somewhere someone hove pdo job
# actual: Find My Item
# predicted:  Complaint
# --------------
# package due tracking recipient box box mean
# actual: Find My Item
# predicted:  Find My Item
# --------------
# send link online claim form
# actual: Complaint
# predicted:  Complaint
# --------------
# likely come tomorrow
# actual: Find My Item
# predicted:  Enquiry
# --------------
# possible ask post man remember delivering package posted
# actual: Enquiry
# predicted:  Complaint
# --------------
# postoffice oh yeah duhh tweet 😂 😂 sorri
# actual: Enquiry
# predicted:  Engagement
# --------------
# failure deliver time pay class service card time end
# actual: Find My Item
# predicted:  Complaint
# --------------
# mojgovuk court action taken someone paper party signed service used
# actual: Engagement
# predicted:  Complaint
# --------------
# parcelforce thankyou clicked link given automatically went onto website 😪 💆 🏾
# actual: Other
# predicted:  Enquiry
# --------------
# delivery friday matracking_number received anything
# actual: Find My Item
# predicted:  Find My Item
# --------------
# contact regard postcode location change used warwickshire boundary hasn changed though
# actual: Enquiry
# predicted:  Find My Item
# --------------
# reply
# actual: Complaint
# predicted:  Find My Item
# --------------
# expecting neighbour received parcel fail
# actual: Find My Item
# predicted:  Complaint
# --------------
# hr take hr
# actual: Complaint
# predicted:  Find My Item
# --------------
# wait till monday highly annoy
# actual: Enquiry
# predicted:  Complaint
# --------------
# gee thanks mr postman put spammy leaflet box straight recycling bin
# actual: Engagement
# predicted:  Complaint
# --------------
# where info ref number either cheer
# actual: Enquiry
# predicted:  Complaint
# --------------
# thieving wanker catch posture tomorrow smash fucking face
# actual: Other
# predicted:  Complaint
# --------------
# see xxdanielle da postcode close bristol where
# actual: Complaint
# predicted:  Find My Item
# --------------
# called service apparently delivered noticed large expensive piece mail
# actual: Find My Item
# predicted:  Complaint
# --------------
#
# actual: Enquiry
# predicted:  Complaint
# --------------
# immiazalea expressandstar submit claim half info make claim ha ripped loststolendisappeared 🙄
# actual: Engagement
# predicted:  Complaint
# --------------
# puddenandpie slip hub shanem
# actual: Engagement
# predicted:  Engagement
# --------------
# find where special delivery
# actual: Complaint
# predicted:  Find My Item
# --------------
# sick use chocolate teapot 😡 😡
# actual: Find My Item
# predicted:  Complaint
# --------------
# non sarcasitic thanks britishairways thursday evening using avios
# actual: Engagement
# predicted:  Complaint
# --------------
# philipastewart least lid
# actual: Engagement
# predicted:  Complaint
# --------------
# order first class signed click drop where see where drop
# actual: Enquiry
# predicted:  Find My Item
# --------------
# mail delivery due pressure election literature going wakeexpress
# actual: Enquiry
# predicted:  Engagement
# --------------
# hii redelivery done urgent number post office leicester le
# actual: Enquiry
# predicted:  Complaint
# --------------
# redirect redirect tracked contact returned sender rather redirected
# actual: Complaint
# predicted:  Find My Item
# --------------
# luck
# actual: Complaint
# predicted:  Engagement
# --------------
# received postal ballot conplaint canno filed detail dailymailuk skynewspolit
# actual: Complaint
# predicted:  Engagement
# --------------
# dropped purse outside didn realise post man knocked door gave son bestpostieever
# actual: Other
# predicted:  Complaint
# --------------
# expressingwordz detail
# actual: Find My Item
# predicted:  Enquiry
# --------------
# refused reply tweet delightfully finished worry asked simple q 😠
# actual: Enquiry
# predicted:  Complaint
# --------------
# answer depot close give phone number depot
# actual: Enquiry
# predicted:  Find My Item
# --------------
# though campaigning stop tuesday libdems leaflet btreewithamlibs fail manchester shameful
# actual: Engagement
# predicted:  Complaint
# --------------
# bamptonoxfordshire postman woman nothing short wond
# actual: Other
# predicted:  Complaint
# --------------
# possible delivered northern ireland stay kilmarnock 🤔
# actual: Find My Item
# predicted:  Find My Item
# --------------
# worst emailing morning rang left card 😊 😊
# actual: Find My Item
# predicted:  Complaint
# --------------
# crieff post office ever reopen ha sneakily closed without consultation strathearnros
# actual: Engagement
# predicted:  Complaint
# --------------
# tracked parcel tracking_number medicine holiday tomorrow evening arrive tomorrow
# actual: Find My Item
# predicted:  Find My Item
# --------------
# pension deferred wage solidarity cwunews member retirement poverty labour must renationalise
# actual: Enquiry
# predicted:  Engagement
# --------------
# gray sorting office closed three part unforeseen industrial action thecwu
# actual: Engagement
# predicted:  Complaint
# --------------
# asap team tweet
# actual: Find My Item
# predicted:  Engagement
# --------------
# til never send parcel failed guaranteed delivery refused urgent parcel useless
# actual: Enquiry
# predicted:  Complaint
# --------------
# thanks mugging right love
# actual: Complaint
# predicted:  Other
# --------------
# packet contains prescription spec insured £ cost £ appear lost long claim holiday
# actual: Find My Item
# predicted:  Complaint
# --------------
# paid £ extra delivery thursday morning waiting later
# actual: Complaint
# predicted:  Find My Item
# --------------
# where post man
# actual: Enquiry
# predicted:  Complaint
# --------------
# posted parcel usa apr ha arrived put complaint
# actual: Complaint
# predicted:  Find My Item
# --------------
# replied
# actual: Find My Item
# predicted:  Enquiry
# --------------
# broncoabroad gave absolutely ridicul
# actual: Engagement
# predicted:  Complaint
# --------------
# tell signed parcel robot answering service understand yorkshire aent
# actual: Enquiry
# predicted:  Complaint
# --------------
# address year random mail live
# actual: Enquiry
# predicted:  Complaint
# --------------
# straighten gold postbox teddington mofarah fall
# actual: Complaint
# predicted:  Engagement
# --------------
# paying international signed dont
# actual: Find My Item
# predicted:  Complaint
# --------------
# proof dog love postie ralph showering postie james affection ☺ ️ 💕
# actual: Other
# predicted:  Complaint
# --------------
# queue long
# actual: Enquiry
# predicted:  Complaint
# --------------
# concerned member beles branch refused customer large p
# actual: Enquiry
# predicted:  Complaint
# --------------
# big inconvenience honest side town far understand logic
# actual: Enquiry
# predicted:  Complaint
# --------------
# mean impossible everyone split bring liampayne
# actual: Complaint
# predicted:  Find My Item
# --------------
# procedure delivering unoupied address thanks
# actual: Enquiry
# predicted:  Complaint
# --------------
# meant two parcel delivered instead received email unable deliver second
# actual: Find My Item
# predicted:  Complaint
# --------------
# jadeybabezz jadey sorry delay tracking number look
# actual: Complaint
# predicted:  Find My Item
# --------------
# presumably found later bin outside tory party office
# actual: Find My Item
# predicted:  Complaint
# --------------
# informed investigate going week wednesday anydanger queenwontbehappi
# actual: Complaint
# predicted:  Find My Item
# --------------
# something done 😡 bloody useless postman delivery
# actual: Enquiry
# predicted:  Complaint
# --------------
# sandy guy went extra mile brining parcel find thank making collect
# actual: Other
# predicted:  Complaint
# --------------
# postoffice collection post office joke post code wrong waybehind post office ask where
# actual: Complaint
# predicted:  Enquiry
# --------------
# card post yesterday reference number 👎 🏻 arrange delivered
# actual: Find My Item
# predicted:  Complaint
# --------------
# happened never arrived march glad emergency freepost lostpost
# actual: Find My Item
# predicted:  Complaint
# --------------
# mail ha posted address receiv
# actual: Find My Item
# predicted:  Complaint
# --------------
# received text ha delivered neighbour nothing door tracking_number where
# actual: Complaint
# predicted:  Find My Item
# --------------
# trying return sender delivery something never posted
# actual: Enquiry
# predicted:  Find My Item
# --------------
#
# actual: Enquiry
# predicted:  Complaint
# --------------
# oh oracle mail posted standard germany scotland two nd class stamp
# actual: Enquiry
# predicted:  Complaint
# --------------
# hey looking
# actual: Complaint
# predicted:  Find My Item
# --------------
# bank sign transaction sure detail correct thanks
# actual: Complaint
# predicted:  Complaint
# --------------
# missed parcel birthday present told collect
# actual: Complaint
# predicted:  Complaint
# --------------
# problem parcel delivered missing house number parcel return address
# actual: Find My Item
# predicted:  Complaint
# --------------
# handwriting reveals ha discovered study writing writer
# actual: Engagement
# predicted:  Complaint
# --------------
# kirstyxquinn redeliver area kirsty time arrive jm
# actual: Find My Item
# predicted:  Complaint
# --------------
# furious handling complaint parcel supposed arrive hasn 😡
# actual: Find My Item
# predicted:  Complaint
# --------------
# east kilbride tracked parcel ha delivered non existent address random ha mail
# actual: Complaint
# predicted:  Find My Item
# --------------

# %% [markdown]
# ### Show Most Imformative Features

# %%
def show_most_informative_features(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print( "\t%.4f\t%-15s\t\t%.4f\t%-15s" % (coef_1, fn_1, coef_2, fn_2))

# %%
# vectorizer = text_clf.named_steps['vect']
# clf = text_clf.named_steps['clf']

# #The above print shows the top 20 lowest values (less predictive features) in the first column 
# #and the top 20 high values (highest predictive features) in the second column.
# show_most_informative_features(vectorizer,clf,n=200)

# %%
import seaborn as sns; sns.set()
mat = confusion_matrix(y_test, predicted_svm)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=y_train, yticklabels=y_train)
plt.xlabel('true label')
plt.ylabel('predicted label');
